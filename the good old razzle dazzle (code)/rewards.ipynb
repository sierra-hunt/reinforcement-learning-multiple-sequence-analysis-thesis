# %% [markdown]
# # HELLO DEAR READER!
# This notebook is for analysis of different rewards. Read the original paper at LINK for a quick understanding of what's going on.

# %% [markdown]
# ### Original configuration file

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import random
import os
import json
import subprocess
from collections import deque
from typing import Dict, List
from Bio.Align import substitution_matrices
import itertools, numpy as np

class Config:
    # INDELible Configuration (Section 5.1)
    INDELIBLE_PATH = "indelible_1.03_Windows.exe"
    SYNTHETIC_DIR = "synthetic_data"
    
    # RL Configuration (Section 5.3.1)
    DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
    MEMORY_CAPACITY = 50000  # Prioritized replay buffer size
    BATCH_SIZE = 512        
    GAMMA = 0.99            # Discount factor
    LR = 0.0001             # Learning rate
    TARGET_UPDATE = 500     # Target network update frequency
    MAX_SEQ_LENGTH = 100    # Maximum sequence length (level 50)
    
    # Evaluation Parameters
    EVAL_EPISODES = 20    # Increased for robust evaluation
    
    # Curriculum Parameters (Section 5.1)
    CURRICULUM_LEVELS = 50  # Full curriculum range
    MIN_SEQ_LENGTH = 10     # Level 1 starting length
    MAX_SEQ_LENGTH = 100    # Level 50 maximum length
    MIN_SEQUENCES = 2       # Starting number of sequences
    MAX_SEQUENCES = 9       # Maximum number of sequences
    NUM_OF_SEQUENCES = 100  # Replicates per level
    
    # Biological Parameters (Section 5.1)
    AMINO_ACIDS = ['-'] + list("ACDEFGHIKLMNPQRSTVWY")
    SUBSTITUTION_MODEL = "WAG"
    INDEL_MODEL_PARAMS = {
        'pow_shape': 1.7,    # Power law shape parameter
        'pow_scale': 100,    # Power law scale parameter
        'min_indel_rate': 0.03,  # Starting indel rate
        'max_indel_rate': 0.05   # Maximum indel rate
    }
    
    # Scoring Parameters (Section 5.2)
    BLOSUM_MATRIX = substitution_matrices.load("BLOSUM62")
    GAP_PENALTY = -6         # For contiguous gaps
    GAP_OPEN_PENALTY = -10   # For opening new gaps
    GAP_EXTEND_PENALTY = -1  # For extending existing gaps

# %% [markdown]
# ### Curriculum creation

# %%
from typing import Dict, List, Optional, Tuple
class INDELibleWrapper:
    """Wrapper for INDELible sequence simulation (Section 5.1)"""
    @staticmethod
    def generate_control_file(output_dir: str, params: Dict):
        """Generate control file with evolutionary parameters"""
        # Calculate level-dependent indel rate
        level = int(params['name'].split('_')[1])
        indel_rate = Config.INDEL_MODEL_PARAMS['min_indel_rate'] + \
                   (level/Config.CURRICULUM_LEVELS) * \
                   (Config.INDEL_MODEL_PARAMS['max_indel_rate'] - Config.INDEL_MODEL_PARAMS['min_indel_rate'])
        
        control_content = f"""[TYPE] AMINOACID 2
        
[MODEL] model_{params['name']}
[submodel] {Config.SUBSTITUTION_MODEL}
[statefreq] {' '.join(map(str, params['state_freqs']))}
[indelmodel] POW {Config.INDEL_MODEL_PARAMS['pow_shape']} {Config.INDEL_MODEL_PARAMS['pow_scale']}
[indelrate] {indel_rate}

[TREE] tree_{params['name']} {params['newick_tree']}

[PARTITIONS] partition_{params['name']}
[tree_{params['name']} model_{params['name']} {params['length']}]

[EVOLVE] partition_{params['name']} {params['num_simulations']} {params['name']}
"""
        with open(os.path.join(output_dir, "control.txt"), 'w') as f:
            f.write(control_content)

    @staticmethod
    def run(output_dir: str) -> bool:
        """Execute INDELible simulation"""
        try:
            result = subprocess.run(
                [Config.INDELIBLE_PATH],
                cwd=output_dir,
                capture_output=True,
                text=True,
                check=True
            )
            
            if "ERROR" in result.stdout:
                error_lines = [line for line in result.stdout.split('\n') if "ERROR" in line]
                raise RuntimeError("\n".join(error_lines))
            
            return True
        except subprocess.CalledProcessError as e:
            print(f"INDELible failed with exit code {e.returncode}")
            print(f"Output:\n{e.stdout}")
            print(f"Error:\n{e.stderr}")
            return False
        except Exception as e:
            print(f"Error running INDELible: {str(e)}")
            return False

def parse_phy_file(file_path: str) -> List[List[str]]:
    """Parse INDELible output file to extract alignments"""
    alignments = []
    current_block = []
    
    with open(file_path, 'r') as f:
        for line in f:
            line = line.strip()
            if not line:
                if current_block:
                    alignments.append(current_block)
                    current_block = []
                continue
                
            if line[0].isdigit():
                continue
                
            parts = line.split()
            if len(parts) >= 2:
                current_block.append(parts[1])
    
    if current_block:
        alignments.append(current_block)
    
    return alignments

def generate_evolutionary_parameters(level: int):
    """Generate parameters for evolutionary simulation (Section 5.1)"""
    # Calculate number of sequences for this level
    num_seqs = Config.MIN_SEQUENCES + \
              (level % (Config.MAX_SEQUENCES - Config.MIN_SEQUENCES + 1))
    
    # Calculate sequence length with curriculum progression
    seq_length = Config.MIN_SEQ_LENGTH + \
               int((level / Config.CURRICULUM_LEVELS) * \
               (Config.MAX_SEQ_LENGTH - Config.MIN_SEQ_LENGTH))
    
    # Create Newick tree with equal branch lengths
    branches = ",".join(f"Seq{i+1}:0.1" for i in range(num_seqs))
    newick_tree = f"({branches});"
    
    return {
        'name': f"level_{level}",
        'matrix': Config.SUBSTITUTION_MODEL,
        'state_freqs': [0.05]*20,  # Uniform state frequencies
        'pow_shape': Config.INDEL_MODEL_PARAMS['pow_shape'],
        'pow_scale': Config.INDEL_MODEL_PARAMS['pow_scale'],
        'newick_tree': newick_tree,
        'length': seq_length,
        'num_simulations': Config.NUM_OF_SEQUENCES
    }

def process_indelible_output(output_dir: str, params: Dict) -> Optional[List[Dict]]:
    """Process INDELible output into multiple training samples (one per alignment block)"""
    try:
        phy_file = os.path.join(output_dir, f"{params['name']}_TRUE.phy")
        if not os.path.exists(phy_file):
            return None
            
        alignment_blocks = parse_phy_file(phy_file)
        if not alignment_blocks:
            return None
            
        samples = []
        for block_idx, true_alignment in enumerate(alignment_blocks):
            sequences = [seq.replace('-', '') for seq in true_alignment]
            samples.append({
                'sequences': sequences,
                'true_alignment': true_alignment,
                'length': params['length'],
                'num_sequences': len(sequences),
                'block_idx': block_idx
            })
            
        return samples
    except Exception as e:
        print(f"Error processing output: {str(e)}")
        return None

def generate_synthetic_curriculum():
    """Generate synthetic alignment curriculum using ALL alignment blocks"""
    os.makedirs(Config.SYNTHETIC_DIR, exist_ok=True)
    curriculum = []
    
    for level in range(1, Config.CURRICULUM_LEVELS + 1):
        level_dir = os.path.join(Config.SYNTHETIC_DIR, f"level_{level}")
        os.makedirs(level_dir, exist_ok=True)
        
        params = generate_evolutionary_parameters(level)
        INDELibleWrapper.generate_control_file(level_dir, params)
        
        if INDELibleWrapper.run(level_dir):
            all_samples = process_indelible_output(level_dir, params)
            if all_samples:
                for sample in all_samples:
                    curriculum.append({
                        'level': level,
                        'sample': sample,
                        'params': params,
                        'name': f"Level {level}-{sample['block_idx']}",
                        'episodes': 300 + level * 150,
                        'epsilon_start': max(0.2, 1.0 - (level * 0.15)),
                        'epsilon_end': max(0.05, 0.15 - (level * 0.02))
                    })
                print(f"Generated level {level} with {len(all_samples)} alignment blocks")
            else:
                print(f"Failed to process output for level {level}")
        else:
            print(f"INDELible failed for level {level}")
    
    return curriculum

curriculum = generate_synthetic_curriculum()
# Out:
# Generated level 1 with 100 alignment blocks
# Generated level 2 with 100 alignment blocks
# Generated level 3 with 100 alignment blocks
# Generated level 4 with 100 alignment blocks
# Generated level 5 with 100 alignment blocks
# Generated level 6 with 100 alignment blocks
# Generated level 7 with 100 alignment blocks
# Generated level 8 with 100 alignment blocks
# Generated level 9 with 100 alignment blocks
# Generated level 10 with 100 alignment blocks
# Generated level 11 with 100 alignment blocks
# Generated level 12 with 100 alignment blocks
# Generated level 13 with 100 alignment blocks
# Generated level 14 with 100 alignment blocks
# Generated level 15 with 100 alignment blocks
# Generated level 16 with 100 alignment blocks
# Generated level 17 with 100 alignment blocks
# Generated level 18 with 100 alignment blocks
# Generated level 19 with 100 alignment blocks
# Generated level 20 with 100 alignment blocks
# Generated level 21 with 100 alignment blocks
# Generated level 22 with 100 alignment blocks
# Generated level 23 with 100 alignment blocks
# Generated level 24 with 100 alignment blocks
# Generated level 25 with 100 alignment blocks
# Generated level 26 with 100 alignment blocks
# Generated level 27 with 100 alignment blocks
# Generated level 28 with 100 alignment blocks
# Generated level 29 with 100 alignment blocks
# Generated level 30 with 100 alignment blocks
# Generated level 31 with 100 alignment blocks
# Generated level 32 with 100 alignment blocks
# Generated level 33 with 100 alignment blocks
# Generated level 34 with 100 alignment blocks
# Generated level 35 with 100 alignment blocks
# Generated level 36 with 100 alignment blocks
# Generated level 37 with 100 alignment blocks
# Generated level 38 with 100 alignment blocks
# Generated level 39 with 100 alignment blocks
# Generated level 40 with 100 alignment blocks
# Generated level 41 with 100 alignment blocks
# Generated level 42 with 100 alignment blocks
# Generated level 43 with 100 alignment blocks
# Generated level 44 with 100 alignment blocks
# Generated level 45 with 100 alignment blocks
# Generated level 46 with 100 alignment blocks
# Generated level 47 with 100 alignment blocks
# Generated level 48 with 100 alignment blocks
# Generated level 49 with 100 alignment blocks
# Generated level 50 with 100 alignment blocks

# %% [markdown]
# ### The Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import random
import os
import json
import subprocess
from collections import deque
from typing import Dict, List
from Bio.Align import substitution_matrices

class BaseProteinAlignmentEnv:
    """Shared base class implementing the MDP formulation (Section 5.2)"""
    def __init__(self, sequences, true_alignment=None):
        # Validate input sequences
        if not sequences:
            raise ValueError("Empty sequence list provided")
        if any(len(seq) == 0 for seq in sequences):
            raise ValueError("One or more sequences are empty")
            
        self.sequences = sequences
        self.true_alignment = true_alignment
        self.n_seqs = len(sequences)
        self.max_len = max(len(s) for s in sequences)
        
        # Action space construction (2^n + n possible actions)
        self.action_space = self._build_action_space()
        self.action_descriptions = self._build_action_descriptions()
        self.aa_to_idx = {aa: i for i, aa in enumerate(Config.AMINO_ACIDS)}
        
        # Hybrid state representation (Section 5.2)
        self.state_size = self._calculate_state_size()
        self.reset()

    def _build_action_space(self):
        """Construct action space with all valid combinations (Section 5.2)"""
        actions = []
        # All possible advancement combinations (2^n - 1)
        for i in range(1, 2**self.n_seqs):
            action = tuple(int(b) for b in f"{i:0{self.n_seqs}b}")
            actions.append(action)
        
        # Gap insertion actions (n additional actions)
        for seq_idx in range(self.n_seqs):
            gap_action = [0] * self.n_seqs
            gap_action[seq_idx] = 1
            actions.append(tuple(gap_action))
            
        return actions

    def _build_action_descriptions(self):
        """Create human-readable action descriptions"""
        desc = []
        for action in self.action_space:
            parts = []
            for i, a in enumerate(action):
                if a:
                    parts.append(f"Advance seq{i+1}" if a == 1 else f"Gap seq{i+1}")
            desc.append(" + ".join(parts) if parts else "No-op")
        return desc

    def _calculate_state_size(self):
        """Calculate state vector size (Section 5.2)"""
        # Local features: current column AA composition
        local_features = len(Config.AMINO_ACIDS)
        
        # Lookahead features: next 3 AAs for each sequence
        lookahead_features = 3 * len(Config.AMINO_ACIDS) * self.n_seqs
        
        # Global features: alignment progress
        progress_features = 2 * self.n_seqs
        
        # Gap context features
        gap_features = 4
        
        return local_features + lookahead_features + progress_features + gap_features

    def reset(self):
        """Initialize a new alignment episode"""
        self.aligned = [[] for _ in range(self.n_seqs)]
        self.remaining = [list(seq) for seq in self.sequences]
        self.original_lengths = [len(seq) for seq in self.sequences]
        self.gap_status = [False] * self.n_seqs
        return self._get_state()

    def _get_gap_context(self):
        """Calculate gap-related features (Section 5.2)"""
        if not self.aligned[0]:
            return np.zeros(4)

        gap_features = np.zeros(4)
        last_col = [seq[-1] if seq else '-' for seq in self.aligned]

        # 1. Current gap ratio in last column
        gap_features[0] = last_col.count('-') / self.n_seqs

        # 2. Contiguous gap ratio
        if len(self.aligned[0]) > 1:
            prev_col = [seq[-2] if len(seq)>1 else '-' for seq in self.aligned]
            gap_features[1] = sum(1 for a,b in zip(last_col, prev_col) if a==b=='-') / self.n_seqs

        # 3. True alignment gap match (if available)
        if self.true_alignment and len(self.aligned[0]) <= len(self.true_alignment[0]):
            target_col = [seq[len(self.aligned[0])-1] for seq in self.true_alignment]
            gap_features[2] = sum(1 for a,b in zip(last_col, target_col) if a==b=='-') / self.n_seqs

        # 4. Total gap ratio in alignment
        total_gaps = sum(seq.count('-') for seq in self.aligned)
        gap_features[3] = total_gaps / (self.n_seqs * len(self.aligned[0])) if self.aligned[0] else 0

        return gap_features

    def _get_state(self):
        """Construct the hybrid state vector (Section 5.2)"""
        state = np.zeros(self.state_size, dtype=np.float32)
        offset = 0
        
        # 1. Current column amino acid composition
        if self.aligned and len(self.aligned[0]) > 0:
            last_col = [seq[-1] for seq in self.aligned]
            for aa in last_col:
                if aa in self.aa_to_idx:
                    state[offset + self.aa_to_idx[aa]] = 1
        offset += len(Config.AMINO_ACIDS)
        
        # 2. Lookahead features (next 3 amino acids)
        for i in range(self.n_seqs):
            if self.remaining[i]:
                for lookahead in range(3):
                    if len(self.remaining[i]) > lookahead:
                        aa = self.remaining[i][lookahead]
                        if aa in self.aa_to_idx:
                            state[offset + lookahead * len(Config.AMINO_ACIDS) + self.aa_to_idx[aa]] = 1.0 / (lookahead + 1)
            offset += 3 * len(Config.AMINO_ACIDS)
        
        # 3. Alignment progress features
        for i in range(self.n_seqs):
            # Safe division for alignment progress
            state[offset + i] = len(self.aligned[i]) / max(1, self.max_len)
            
            # Safe division for remaining ratio
            seq_len = len(self.sequences[i])
            remaining_len = len(self.remaining[i])
            if seq_len > 0:
                state[offset + self.n_seqs + i] = remaining_len / seq_len
            else:
                state[offset + self.n_seqs + i] = 0
        offset += 2 * self.n_seqs
        
        # 4. Gap context features
        state[offset:offset+4] = self._get_gap_context()
        
        return state

    def _verify_alignment_integrity(self):
        """Validate that no amino acids were lost during alignment"""
        for i in range(self.n_seqs):
            aligned_chars = len([c for c in self.aligned[i] if c != '-'])
            remaining_chars = len(self.remaining[i])
            assert aligned_chars + remaining_chars == self.original_lengths[i], \
                f"Sequence {i} lost amino acids! Original: {self.original_lengths[i]}, Aligned: {aligned_chars}, Remaining: {remaining_chars}"

    def step(self, action_idx):
        """Execute one alignment step (Section 5.2)"""
        action = self.action_space[action_idx]
        new_column = []
        new_gap_status = [False] * self.n_seqs
        
        # Process each sequence according to action
        for i in range(self.n_seqs):
            if action[i] and self.remaining[i]:
                new_column.append(self.remaining[i].pop(0))
                new_gap_status[i] = False
            else:
                new_column.append('-')
                new_gap_status[i] = True
        
        prev_gap_status = self.gap_status
        self.gap_status = new_gap_status
        
        # Add the new column to the alignment
        for i in range(self.n_seqs):
            self.aligned[i].append(new_column[i])
        
        # Check termination conditions
        done = all(len(seq) == 0 for seq in self.remaining)
        if len(self.aligned[0]) >= self.max_len * 2:
            if not done:
                reward = -100 * sum(len(seq) for seq in self.remaining)
                self._verify_alignment_integrity()
                return reward, self._get_state(), True
            done = True

        current_alignment = [''.join(seq) for seq in self.aligned]
        self._verify_alignment_integrity()
        
        reward = self._calculate_reward(current_alignment, done)
        return reward, self._get_state(), done

    def _calculate_reward(self, current_alignment, done):
        raise NotImplementedError("Implemented in child classes")

class AlignmentQNetwork(nn.Module):
    """Q-network architecture (Section 5.3.3)"""
    def __init__(self, input_dim, output_dim):
        super().__init__()
        # 4-layer MLP with layer normalization
        self.fc1 = nn.Linear(input_dim, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, output_dim)
        
        self.layer_norm1 = nn.LayerNorm(256)
        self.layer_norm2 = nn.LayerNorm(128)
        self.layer_norm3 = nn.LayerNorm(64)
        self.dropout = nn.Dropout(0.2)  # 20% dropout

    def forward(self, x):
        x = F.relu(self.layer_norm1(self.fc1(x)))
        x = self.dropout(x)
        x = F.relu(self.layer_norm2(self.fc2(x)))
        x = self.dropout(x)
        x = F.relu(self.layer_norm3(self.fc3(x)))
        return self.fc4(x)

class DQNAgent:
    """DQN agent with prioritized experience replay (Section 5.3)"""
    def __init__(self, state_dim, action_dim, action_space):
        self.policy_net = AlignmentQNetwork(state_dim, action_dim).to(Config.DEVICE)
        self.target_net = AlignmentQNetwork(state_dim, action_dim).to(Config.DEVICE)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        
        # Optimizer with weight decay and learning rate scheduling
        self.optimizer = torch.optim.AdamW(self.policy_net.parameters(), 
                                          lr=Config.LR, 
                                          weight_decay=1e-4)
        self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            self.optimizer, 'min', patience=50, factor=0.5)
        
        self.memory = deque(maxlen=Config.MEMORY_CAPACITY)
        self.steps = 0
        self.action_space = action_space
        self.action_dim = action_dim
        self.state_dim = state_dim

    def select_action(self, state, epsilon):
        """Epsilon-greedy action selection"""
        if random.random() < epsilon:
            return random.randint(0, self.action_dim-1)
        
        with torch.no_grad():
            state_tensor = torch.FloatTensor(state).unsqueeze(0).to(Config.DEVICE)
            return self.policy_net(state_tensor).argmax().item()

    def store_transition(self, state, action, next_state, reward, done):
        """Store transition in replay buffer"""
        self.memory.append((state, action, next_state, reward, done))

    def update(self):
        """Update policy network with prioritized experience replay"""
        if len(self.memory) < Config.BATCH_SIZE:
            return None
        
        batch = random.sample(self.memory, Config.BATCH_SIZE)
        states, actions, next_states, rewards, dones = zip(*batch)
        
        states = torch.FloatTensor(np.array(states)).to(Config.DEVICE)
        actions = torch.LongTensor(actions).to(Config.DEVICE)
        next_states = torch.FloatTensor(np.array(next_states)).to(Config.DEVICE)
        rewards = torch.FloatTensor(rewards).to(Config.DEVICE)
        dones = torch.FloatTensor(dones).to(Config.DEVICE)
        
        # Current Q values
        current_q = self.policy_net(states).gather(1, actions.unsqueeze(1))
        
        # Double DQN target calculation
        with torch.no_grad():
            next_actions = self.policy_net(next_states).argmax(1)
            next_q = self.target_net(next_states).gather(1, next_actions.unsqueeze(1))
            target_q = rewards + (1 - dones) * Config.GAMMA * next_q.squeeze()
        
        # Huber loss for more stable training
        loss = F.smooth_l1_loss(current_q.squeeze(), target_q)
        
        # Optimize with gradient clipping
        self.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.policy_net.parameters(), 1.0)
        self.optimizer.step()
        self.scheduler.step(loss)

        # Update target network periodically
        if self.steps % Config.TARGET_UPDATE == 0:
            self.target_net.load_state_dict(self.policy_net.state_dict())
        
        self.steps += 1
        return loss.item()

def evaluate_agent(agent, sequences, true_alignment=None, scoring_method='sp'):
    """Comprehensive agent evaluation with intermediate state tracking"""
    # Skip evaluation if we have invalid sequences
    if any(len(seq) == 0 for seq in sequences):
        print("Skipping evaluation due to empty sequences")
        return {
            "avg_reward": 0,
            "avg_sp_score": 0,
            "perfect_match_rate": 0,
            "column_accuracy": 0,
            "avg_alignment_length": 0,
            "reward_std": 0,
            "sp_score_std": 0,
            "all_rewards": [],
            "all_lengths": [],
            "alignments": [],
            "state_sp_correlations": [],
            "state_feature_importance": None
        }
    
    # Initialize environment based on scoring method
    if scoring_method == 'true':
        env = TrueAlignmentProteinEnv(sequences, true_alignment)
    elif scoring_method == 'blosum':
        env = TrueAlignmentBlosumProteinEnv(sequences, true_alignment)
    elif scoring_method == 'rlalign':
        env = RLALIGNProteinEnv(sequences)
    elif scoring_method == 'msadrl':
        env = MSADRLProteinEnv(sequences)
    elif scoring_method == 'dqnalign':
        env = DQNAlignProteinEnv(sequences)
    elif scoring_method == 'dnpmsa':
        env = DNPMSAProteinEnv(sequences)
    elif scoring_method == 'edgealign':
        env = EdgeAlignProteinEnv(sequences)
    elif scoring_method == 'dpamsa':
        env = DPAMSAProteinEnv(sequences)
    elif scoring_method == 'intellialign':
        env = IntelliAlignProteinEnv(sequences)

    
    # Evaluation metrics
    total_rewards = []
    perfect_matches = 0
    alignment_lengths = []
    produced_alignments = []
    sp_scores = []
    column_accuracies = []
    state_sp_correlations = []
    all_state_features = []
    all_sp_scores = []

    for _ in range(Config.EVAL_EPISODES):
        state = env.reset()
        episode_reward = 0
        done = False
        episode_states = []
        episode_sp_scores = []

        while not done:
            action = agent.select_action(state, epsilon=0.01)  # Minimal exploration
            reward, state, done = env.step(action)
            episode_reward += reward
            
            # Track intermediate state and SP score
            current_alignment = [''.join(seq) for seq in env.aligned]
            sp_score = SPProteinAlignmentEnv._calculate_sp_score(env, current_alignment)
            
            episode_states.append(state)
            episode_sp_scores.append(sp_score)

        # Store episode results
        total_rewards.append(episode_reward)
        current_alignment = [''.join(seq) for seq in env.aligned]
        produced_alignments.append(current_alignment)
        
        # Calculate final SP score
        final_sp_score = SPProteinAlignmentEnv._calculate_sp_score(env, current_alignment)
        sp_scores.append(final_sp_score)
        
        # Calculate column accuracy if true alignment available
        if true_alignment:
            min_len = min(len(current_alignment[0]), len(true_alignment[0]))
            correct_cols = 0
            for col in range(min_len):
                if tuple(seq[col] for seq in current_alignment) == tuple(seq[col] for seq in true_alignment):
                    correct_cols += 1
            column_accuracies.append(correct_cols / min_len if min_len > 0 else 0)

        if true_alignment and current_alignment == true_alignment:
            perfect_matches += 1
        alignment_lengths.append(len(env.aligned[0]))
        
        # Calculate state-SP correlation for this episode
        if len(episode_states) > 1:
            # Convert to numpy arrays
            states_array = np.array(episode_states)
            sp_array = np.array(episode_sp_scores)
            
            # Calculate correlation for each state feature
            feature_correlations = []
            for i in range(states_array.shape[1]):
                feature_correlations.append(np.corrcoef(states_array[:, i], sp_array)[0,1])
            
            state_sp_correlations.append(feature_correlations)
            all_state_features.extend(episode_states)
            all_sp_scores.extend(episode_sp_scores)

    # Calculate overall feature importance
    feature_importance = None
    if len(all_state_features) > 0:
        states_array = np.array(all_state_features)
        sp_array = np.array(all_sp_scores)
        
        # Calculate correlation for each feature across all episodes
        feature_importance = []
        for i in range(states_array.shape[1]):
            corr = np.corrcoef(states_array[:, i], sp_array)[0,1]
            feature_importance.append(abs(corr))  # Use absolute value of correlation

    # Print example alignments for inspection
    print("\nExample produced alignments:")
    for i in range(min(3, len(produced_alignments))):
        print(f"  {produced_alignments[i]}")

    return {
        "avg_reward": np.mean(total_rewards),
        "avg_sp_score": np.mean(sp_scores),
        "perfect_match_rate": perfect_matches / Config.EVAL_EPISODES if true_alignment else 0,
        "column_accuracy": np.mean(column_accuracies) if column_accuracies else 0,
        "avg_alignment_length": np.mean(alignment_lengths),
        "reward_std": np.std(total_rewards),
        "sp_score_std": np.std(sp_scores),
        "all_rewards": total_rewards,
        "all_lengths": alignment_lengths,
        "alignments": produced_alignments,
        "state_sp_correlations": np.mean(state_sp_correlations, axis=0) if state_sp_correlations else [],
        "state_feature_importance": feature_importance
    }

def train_agent(curriculum, scoring_method='sp'):
    """Training procedure (Section 5.3)"""
    agent = None
    results = {}
    prev_state_size = None

    for stage_idx, stage in enumerate(curriculum):
        print(f"\n=== Starting {stage['name']} ({scoring_method.upper()} scoring) ===")
        
        try:
            # Skip if we have invalid sequences
            if any(len(seq) == 0 for seq in stage['sample']['sequences']):
                print(f"Skipping {stage['name']} due to empty sequences")
                continue
                
            # Create appropriate environment based on pathway
            if scoring_method == 'true':
                env = TrueAlignmentProteinEnv(stage['sample']['sequences'], stage['sample']['true_alignment'])
            elif scoring_method == 'blosum':
                env = TrueAlignmentBlosumProteinEnv(stage['sample']['sequences'], stage['sample']['true_alignment'])
            elif scoring_method == 'rlalign':
                env = RLALIGNProteinEnv(stage['sample']['sequences'])
            elif scoring_method == 'msadrl':
                env = MSADRLProteinEnv(stage['sample']['sequences'])
            elif scoring_method == 'dqnalign':
                env = DQNAlignProteinEnv(stage['sample']['sequences'])
            elif scoring_method == 'dnpmsa':
                env = DNPMSAProteinEnv(stage['sample']['sequences'])
            elif scoring_method == 'edgealign':
                env = EdgeAlignProteinEnv(stage['sample']['sequences'])
            elif scoring_method == 'dpamsa':
                env = DPAMSAProteinEnv(stage['sample']['sequences'])
            elif scoring_method == 'intellialign':
                env = IntelliAlignProteinEnv(stage['sample']['sequences'])
              
            # Reinitialize agent if state size changed (different number of sequences)
            if agent is None or env.state_size != prev_state_size:
                if agent is not None:
                    print(f"Reinitializing agent due to state size change ({prev_state_size} -> {env.state_size})")
                agent = DQNAgent(env.state_size, len(env.action_space), env.action_space)
                prev_state_size = env.state_size

            epsilon = stage['epsilon_start']
            epsilon_decay = (stage['epsilon_end'] / stage['epsilon_start']) ** (1/stage['episodes'])

            training_rewards = []
            losses = []
            best_reward = -float('inf')
            no_improvement = 0

            for episode in range(stage['episodes']):
                state = env.reset()
                total_reward = 0
                done = False

                while not done:
                    action = agent.select_action(state, epsilon)
                    reward, next_state, done = env.step(action)
                    agent.store_transition(state, action, next_state, reward, done)
                    total_reward += reward
                    state = next_state

                loss = agent.update()
                if loss:
                    losses.append(loss)

                # Decay epsilon
                epsilon = max(stage['epsilon_end'], epsilon * epsilon_decay)
                training_rewards.append(total_reward)

                # Early stopping check (Section 5.3.2)
                if total_reward > best_reward:
                    best_reward = total_reward
                    no_improvement = 0
                else:
                    no_improvement += 1

                if no_improvement > 100:
                    print(f"Early stopping at episode {episode} due to no improvement")
                    break

                # Progress reporting
                if episode % 50 == 0 or episode == stage['episodes']-1:
                    avg_reward = np.mean(training_rewards[-50:]) if len(training_rewards) >= 50 else np.mean(training_rewards)
                    avg_loss = np.mean(losses[-50:]) if losses else 0
                    print(f"Episode {episode}, Avg Reward: {avg_reward:.2f}, Avg Loss: {avg_loss:.4f}, Epsilon: {epsilon:.3f}")

            # Evaluate with both metrics
            eval_results = evaluate_agent(
                agent, 
                stage['sample']['sequences'], 
                stage['sample'].get('true_alignment'),
                scoring_method=scoring_method
            )
            
            results[stage['name']] = {
                "training_rewards": training_rewards,
                "losses": losses,
                "eval_results": eval_results,
                "agent": agent,
                "level": stage['level'],
                "scoring_method": scoring_method
            }

            print(f"\nEvaluation for {stage['name']}:")
            print(f"  Average Reward: {eval_results['avg_reward']:.2f} ± {eval_results['reward_std']:.2f}")
            print(f"  Average SP Score: {eval_results['avg_sp_score']:.2f} ± {eval_results['sp_score_std']:.2f}")
            if 'true_alignment' in stage['sample']:
                print(f"  Perfect Match Rate: {eval_results['perfect_match_rate']:.2f}")
                print(f"  Column Accuracy: {eval_results['column_accuracy']:.2f}")
            print(f"  Avg Alignment Length: {eval_results['avg_alignment_length']:.1f}")

        except Exception as e:
            print(f"Error processing {stage['name']}: {str(e)}")
            continue
            
    return agent, results

def save_results(results, filename):
    """Save training results (without agent objects)"""
    serializable_results = {}
    for name, data in results.items():
        serializable_results[name] = {
            'level': data['level'],
            'scoring_method': data['scoring_method'],
            'training_rewards': data['training_rewards'],
            'losses': data['losses'],
            'eval_results': data['eval_results'],
        }
    
    with open(filename, 'w') as f:
        json.dump(serializable_results, f)

def load_results(filename):
    """Load saved results"""
    with open(filename, 'r') as f:
        return json.load(f)

# %% [markdown]
# ### True reward function

# %%
class TrueAlignmentBlosumProteinEnv(BaseProteinAlignmentEnv):
    def _calculate_reward(self, current_alignment, done):
        reward = 0
        
        # 1. Perfect alignment bonus
        if self.true_alignment and current_alignment == self.true_alignment:
            return 100.0  # Standardized perfect alignment reward
        
        # 2. Column-wise matching (normalized by sequence count)
        if self.true_alignment:
            min_len = min(len(current_alignment[0]), len(self.true_alignment[0]))
            for col in range(min_len):
                current_col = tuple(seq[col] for seq in current_alignment)
                true_col = tuple(seq[col] for seq in self.true_alignment)
                
                if current_col == true_col:
                    reward += 2.0  # Perfect column match
                else:
                    for a, b in zip(current_col, true_col):
                        if a == b and a != '-':
                            reward += 0.5  # AA match
                        elif a == '-' and b == '-':
                            reward += 0.1  # Correct gap
                        elif a != b and (a == '-' or b == '-'):
                            reward -= 0.3  # Incorrect gap
        
        # 3. BLOSUM score (normalized)
        if len(self.aligned[0]) > 0:
            last_col = [seq[-1] for seq in self.aligned]
            pairs = 0
            for i in range(self.n_seqs):
                for j in range(i+1, self.n_seqs):
                    a, b = last_col[i], last_col[j]
                    if a != '-' and b != '-':
                        try:
                            reward += Config.BLOSUM_MATRIX[a, b] * 0.05
                        except KeyError:
                            pass
                    elif a == '-' or b == '-':
                        reward += Config.GAP_PENALTY * 0.05
                    pairs += 1
            if pairs > 0:
                reward /= pairs  # Normalize by number of pairs
        
        # 4. Completion bonus (standardized)
        if done and all(len(seq) == 0 for seq in self.remaining):
            reward += 100.0
            
        return float(reward)

class SPProteinAlignmentEnv(BaseProteinAlignmentEnv):
    def _calculate_sp_score(self, current_alignment):
        """Calculate normalized SP score (Section 5.2)"""
        total_score = 0.0
        n_cols = len(current_alignment[0]) if current_alignment else 0
        
        for col_idx in range(n_cols):
            column = [seq[col_idx] for seq in current_alignment]
            
            for i in range(len(column)):
                for j in range(i+1, len(column)):
                    a, b = column[i], column[j]
                    
                    if a == '-' and b == '-':
                        pair_score = 0
                    elif a == '-' or b == '-':
                        # Apply appropriate gap penalty
                        if (a == '-' and self.gap_status[i]) or (b == '-' and self.gap_status[j]):
                            pair_score = Config.GAP_EXTEND_PENALTY
                        else:
                            pair_score = Config.GAP_OPEN_PENALTY
                    else:
                        try:
                            pair_score = Config.BLOSUM_MATRIX[a, b]
                        except KeyError:
                            pair_score = -4  # Default penalty for rare AA pairs
                    
                    total_score += pair_score
        
        # Normalize by number of columns and pairs
        if n_cols > 0:
            total_score /= (n_cols * (self.n_seqs * (self.n_seqs - 1)) / 2)
        
        return total_score


    def _calculate_reward(self, current_alignment, done):
        """Standardized SP score reward"""
        if not current_alignment:
            return 0.0
            
        # Calculate normalized SP score
        sp_score = self._calculate_sp_score(current_alignment)
        
        # Scale to target range (0-100 for perfect alignment)
        reward = sp_score * 50  # Adjusted scaling
        
        # Standard completion bonus
        if done and all(len(seq) == 0 for seq in self.remaining):
            reward += 100.0
            
        return float(reward)


    """RQ1 Pathway: Biological alignment rewards (Equation 2)"""
    def _calculate_reward(self, current_alignment, done):
        reward = 0
        
        # 1. Perfect alignment bonus (R_complete)
        if self.true_alignment and current_alignment == self.true_alignment:
            return 500.0
        
        # 2. Column-wise matching reward (5R_match + 2R_consensus + 0.5R_gap)
        if self.true_alignment:
            min_len = min(len(current_alignment[0]), len(self.true_alignment[0]))
            for col in range(min_len):
                current_col = tuple(seq[col] for seq in current_alignment)
                true_col = tuple(seq[col] for seq in self.true_alignment)
                
                if current_col == true_col:
                    reward += 5.0 * self.n_seqs  # Perfect column match
                else:
                    for a, b in zip(current_col, true_col):
                        if a == b and a != '-':
                            reward += 2.0  # AA match
                        elif a == '-' and b == '-':
                            reward += 0.5  # Correct gap
                        elif a != b and (a == '-' or b == '-'):
                            reward -= 1.0  # Incorrect gap
        
        # 3. BLOSUM score for the last column (70% of reward)
        if len(self.aligned[0]) > 0:
            last_col = [seq[-1] for seq in self.aligned]
            for i in range(self.n_seqs):
                for j in range(i+1, self.n_seqs):
                    a, b = last_col[i], last_col[j]
                    if a != '-' and b != '-':
                        try:
                            reward += Config.BLOSUM_MATRIX[a, b] * 0.7  # Weighted BLOSUM
                        except KeyError:
                            pass
                    elif a == '-' or b == '-':
                        reward += Config.GAP_PENALTY * 0.7  # Weighted gap penalty
        
        # 4. Length penalty (-0.5L_penalty)
        reward -= 0.5 * len(self.aligned[0])
        
        # 5. Completion bonus (100R_complete)
        if done and all(len(seq) == 0 for seq in self.remaining):
            reward += 100.0
            
        return float(reward)

class TrueAlignmentProteinEnv(BaseProteinAlignmentEnv):
    def __init__(self, sequences, true_alignment=None):
        super().__init__(sequences, true_alignment)
        # Dynamic penalty scaling based on sequence length
        self.base_gap_penalty = -2 * (1 + np.log10(max(10, self.max_len)))
        self.progressive_weight = 0.3  # Starts low, increases with progress

    def _calculate_reward(self, current_alignment, done):
        if not current_alignment or not self.true_alignment:
            return 0.0

        reward = 0
        current_progress = len(current_alignment[0])/self.max_len if self.max_len > 0 else 0
        self.progressive_weight = min(1.0, 0.3 + current_progress*0.7)  # Progressive weighting

        # 1. Column-wise alignment scoring (weighted by progress)
        min_cols = min(len(current_alignment[0]), len(self.true_alignment[0]))
        perfect_cols = 0
        
        for col in range(min_cols):
            current_col = [seq[col] for seq in current_alignment]
            true_col = [seq[col] for seq in self.true_alignment]
            
            # Perfect column match (high reward)
            if current_col == true_col:
                perfect_cols += 1
                reward += 8.0 * self.n_seqs * self.progressive_weight
            else:
                # Partial matches
                matches = sum(1 for c,t in zip(current_col, true_col) if c == t and c != '-')
                reward += 2.5 * matches * self.progressive_weight
                
                # Conservative mismatches penalty
                mismatches = sum(1 for c,t in zip(current_col, true_col) if c != t)
                reward -= 0.1 * mismatches

        # 2. Gap pattern scoring (less penalizing early on)
        gap_score = 0
        for seq_idx in range(self.n_seqs):
            aligned = current_alignment[seq_idx]
            true = self.true_alignment[seq_idx]
            
            # Compare gap patterns
            for c, t in zip(aligned, true):
                if c == '-' and t == '-':
                    gap_score += 0.7  # Reward correct gaps
                elif c == '-' or t == '-':
                    gap_score -= 0.3 * (1 - current_progress)  # Reduced early penalty
        
        reward += gap_score * self.n_seqs

        # 3. Completion and length normalization
        if done:
            completion_ratio = sum(1 for seq in self.remaining if len(seq) == 0)/self.n_seqs
            reward += 150.0 * completion_ratio * self.progressive_weight
            
        # Normalize by length and sequence count
        return reward / (min_cols * self.n_seqs) if min_cols > 0 else 0

# %% [markdown]
# ### Alternative reward functions

# %% [markdown]
# These functions are taken from the following papers and have been modified to function as part of our base model implementation, with various scaling factors applied to balance with the original ground truth reward function.
#
# 1. RLALIGN: Kinattinkara Ramakrishnan, R., Singh, J. & Blanchette, M. RLALIGN: A Reinforcement Learning Approach for Multiple Sequence Alignment. in 2018 IEEE 18th International Conference on Bioinformatics and Bioengineering (BIBE) 61–66 (2018). doi:10.1109/BIBE.2018.00019.
# 2. MSADRL: Joeres, R. Multiple Sequence Alignment using Deep Reinforcement Learning. in 101–112 (Gesellschaft für Informatik, Bonn, 2021).
# 3. DQNAlign: Song, Y.-J., Ji, D. J., Seo, H., Han, G.-B. & Cho, D.-H. Pairwise Heuristic Sequence Alignment Algorithm Based on Deep Reinforcement Learning. IEEE Open J Eng Med Biol 2, 36–43 (2021).
# 4. DNPMSA: Zhang, Y., Zhang, Q., Liu, Y., Lin, M. & Ding, C. Multiple Sequence Alignment based on deep Q network with negative feedback policy. Computational Biology and Chemistry 101, 107780 (2022).
# 5. EdgeAlign: Lall, A. & Tallur, S. Deep reinforcement learning-based pairwise DNA sequence alignment method compatible with embedded edge devices. Sci Rep 13, 2773 (2023).
# 6. DPAMSA: Liu, Y. et al. Multiple sequence alignment based on deep reinforcement learning with self-attention and positional encoding. Bioinformatics 39, btad636 (2023).
# 7. IntelliAlign: Κοτζιά, Ε. Solving multiple sequence alignment using deep reinforcement learning. Επίλυση ευθυγράμμισης πολλαπλών ακολουθιών χρησιμοποιώντας βαθιά ενισχυτική μάθηση (2024) doi:10.26265/polynoe-5855.

# %%
class RLALIGNProteinEnv(BaseProteinAlignmentEnv):
    def _calculate_reward(self, current_alignment, done):
        """Standardized RLALIGN reward"""
        if not current_alignment:
            return 0.0
            
        n_cols = len(current_alignment[0])
        n_pairs = (self.n_seqs * (self.n_seqs - 1)) // 2
        reward = 0.0
        
        # Calculate column scores
        for col in range(n_cols):
            column = [seq[col] for seq in current_alignment]
            for i in range(self.n_seqs):
                for j in range(i+1, self.n_seqs):
                    a, b = column[i], column[j]
                    if a == b and a != '-':
                        reward += 0.5  # Match
                    elif a != '-' and b != '-' and a != b:
                        reward -= 0.3  # Mismatch
                    elif a == '-' or b == '-':
                        reward -= 0.2  # Gap penalty
        
        # Normalize and scale
        if n_cols > 0 and n_pairs > 0:
            reward = (reward / (n_cols * n_pairs)) * 50
            
        # Standard completion bonus
        if done:
            reward += 100.0
            
        return float(reward)

class MSADRLProteinEnv(BaseProteinAlignmentEnv):
    def __init__(self, sequences, true_alignment=None, score_type='SP'):
        super().__init__(sequences, true_alignment)
        # MSADRL parameters
        self.score_type = score_type  # 'SP' or 'C'
        self.match_reward = 2.0       # Reward for matching amino acids
        self.mismatch_penalty = -1.0  # Penalty for mismatched amino acids
        self.gap_penalty = -5.0       # Penalty for gaps (protein-specific)
        
    def _calculate_sp_score(self, current_alignment):
        """Calculate SP score according to MSADRL paper"""
        total_score = 0.0
        n_cols = len(current_alignment[0]) if current_alignment else 0
        
        for col_idx in range(n_cols):
            column = [seq[col_idx] for seq in current_alignment]
            
            for i in range(len(column)):
                for j in range(i+1, len(column)):
                    a, b = column[i], column[j]
                    
                    if a == '-' and b == '-':
                        continue  # No score for gap-gap
                    elif a == '-' or b == '-':
                        total_score += self.gap_penalty
                    elif a == b:
                        total_score += self.match_reward
                    else:
                        total_score += self.mismatch_penalty
        
        # Normalize by number of columns and pairs
        if n_cols > 0:
            total_score /= (n_cols * (self.n_seqs * (self.n_seqs - 1)) / 2)
        
        return total_score
    
    def _calculate_c_score(self, current_alignment):
        """Calculate column score (fraction of perfectly aligned columns)"""
        if not current_alignment:
            return 0.0
            
        n_cols = len(current_alignment[0])
        perfect_cols = 0
        
        for col in range(n_cols):
            column = [seq[col] for seq in current_alignment]
            first = column[0]
            if all(c == first for c in column) and first != '-':
                perfect_cols += 1
                
        return perfect_cols / n_cols
      
    def _calculate_reward(self, current_alignment, done):
        """Standardized MSADRL reward"""
        if not current_alignment:
            return 0.0
            
        if self.score_type == 'SP':
            score = self._calculate_sp_score(current_alignment)
            reward = score * 50  # Adjusted scaling
        else:
            score = self._calculate_c_score(current_alignment)
            reward = score * 100  # C-score already 0-1
            
        # Standard completion bonus
        if done:
            reward += 100.0
            
        return float(reward)

class DQNAlignProteinEnv(BaseProteinAlignmentEnv):
    def __init__(self, sequences, true_alignment=None):
        super().__init__(sequences, true_alignment)
        # DQNALIGN parameters
        self.match_reward = 1.0      # Reward for matching amino acids
        self.mismatch_penalty = -1.0 # Penalty for mismatched amino acids
        self.gap_penalty = -1.0      # Penalty for gaps (no distinction between open/extend)
        
    def _calculate_column_score(self, column):
        """Calculate score for a single column"""
        score = 0
        for i in range(len(column)):
            for j in range(i+1, len(column)):
                a, b = column[i], column[j]
                
                if a == '-' and b == '-':
                    continue  # No score for gap-gap
                elif a == '-' or b == '-':
                    score += self.gap_penalty
                elif a == b:
                    score += self.match_reward
                else:
                    score += self.mismatch_penalty
        return score
    
    
    def _calculate_reward(self, current_alignment, done):
        """Standardized DQNAlign reward"""
        if not current_alignment:
            return 0.0
            
        # Score only last column
        last_column = [seq[-1] for seq in current_alignment]
        column_score = self._calculate_column_score(last_column)
        
        # Normalize by max possible column score
        max_pairs = (self.n_seqs * (self.n_seqs - 1)) // 2
        normalized_score = column_score / (max_pairs * self.match_reward) if max_pairs > 0 else 0
        
        # Scale and add completion bonus
        reward = normalized_score * 50
        if done:
            reward += 100.0
            
        return float(reward)

class DNPMSAProteinEnv(BaseProteinAlignmentEnv):
    def __init__(self, sequences, true_alignment=None):
        super().__init__(sequences, true_alignment)
        # DNPMSA-specific parameters
        self.MATCH_REWARD = 5.0       # Reward for matching residues
        self.MISMATCH_PENALTY = -3.0  # Penalty for mismatches
        self.GAP_PENALTY = -4.0       # Penalty for gaps
        self._max_reward = self._calculate_max_reward()
        
    def _calculate_max_reward(self):
        """Calculate maximum possible reward for normalization"""
        max_cols = self.max_len * 2  # Worst case: all gaps
        max_pairs = (self.n_seqs * (self.n_seqs - 1)) // 2
        return max_cols * max_pairs * self.MATCH_REWARD
      
    
    def _calculate_reward(self, current_alignment, done):
        """Standardized DNPMSA reward"""
        if not current_alignment:
            return 0.0
            
        # Calculate raw score
        reward = 0.0
        n_cols = len(current_alignment[0])
        for col in range(n_cols):
            for i in range(self.n_seqs):
                for j in range(i+1, self.n_seqs):
                    a, b = current_alignment[i][col], current_alignment[j][col]
                    if a == '-' or b == '-':
                        reward += self.GAP_PENALTY
                    elif a == b:
                        reward += self.MATCH_REWARD
                    else:
                        reward += self.MISMATCH_PENALTY
        
        # Normalize and scale
        normalized = reward / max(1, self._max_reward)
        reward = normalized * 100
        
        # Standard completion bonus
        if done:
            reward += 100.0
            
        return float(reward)

class EdgeAlignProteinEnv(BaseProteinAlignmentEnv):
    def __init__(self, sequences, true_alignment=None):
        super().__init__(sequences, true_alignment)
        # EDGEALIGN parameters (normalized values from paper)
        self.match_reward = 1.0         # Reward for matching amino acids
        self.mismatch_penalty = -0.6    # Penalty for mismatched amino acids
        self.gap_open_penalty = -1.0    # Penalty for opening a new gap
        self.gap_extend_penalty = -0.4  # Penalty for extending an existing gap
        
    def _calculate_column_score(self, column):
        """Calculate score for a single column with gap tracking"""
        score = 0
        for i in range(len(column)):
            for j in range(i+1, len(column)):
                a, b = column[i], column[j]
                
                if a == '-' and b == '-':
                    continue  # No score for gap-gap
                elif a == '-' or b == '-':
                    # Check if this is a gap opening or extension
                    if (a == '-' and not self.gap_status[i]) or (b == '-' and not self.gap_status[j]):
                        score += self.gap_open_penalty
                    else:
                        score += self.gap_extend_penalty
                elif a == b:
                    score += self.match_reward
                else:
                    score += self.mismatch_penalty
        return score
    def _calculate_reward(self, current_alignment, done):
        """Standardized EdgeAlign reward"""
        if not current_alignment:
            return 0.0
            
        # Score only last column
        last_column = [seq[-1] for seq in current_alignment]
        column_score = self._calculate_column_score(last_column)
        
        # Normalize by max possible
        max_pairs = (self.n_seqs * (self.n_seqs - 1)) // 2
        max_score = max_pairs * self.match_reward
        normalized = column_score / max_score if max_score > 0 else 0
        
        # Scale and add completion bonus
        reward = normalized * 50
        if done:
            reward += 100.0
            
        return float(reward)

class DPAMSAProteinEnv(BaseProteinAlignmentEnv):
    def __init__(self, sequences, true_alignment=None):
        super().__init__(sequences, true_alignment)
        # DPAMSA parameters
        self.match_reward = 2        # Reward for matching amino acids
        self.mismatch_penalty = -1   # Penalty for mismatched amino acids
        self.gap_penalty = -2        # Penalty for gaps
        self.max_sp_per_column = self._calculate_max_sp_per_column()
        
    def _calculate_max_sp_per_column(self):
        """Calculate maximum possible SP score for one column (all matches)"""
        n = self.n_seqs
        return (n * (n - 1)) // 2 * self.match_reward
        
    def _calculate_column_score(self, column):
        """Calculate SP score for a single column"""
        score = 0
        for i in range(len(column)):
            for j in range(i+1, len(column)):
                a, b = column[i], column[j]
                if a == '-' or b == '-':
                    score += self.gap_penalty
                elif a == b:
                    score += self.match_reward
                else:
                    score += self.mismatch_penalty
        return score
        
    def _calculate_reward(self, current_alignment, done):
        """Standardized DPAMSA reward"""
        if not current_alignment:
            return 0.0
            
        # Score only last column
        last_column = [seq[-1] for seq in current_alignment]
        column_score = self._calculate_column_score(last_column)
        
        # Normalize and scale
        normalized = column_score / self.max_sp_per_column if self.max_sp_per_column > 0 else 0
        reward = normalized * 50
        
        # Standard completion bonus
        if done:
            reward += 100.0
            
        return float(reward)

class IntelliAlignProteinEnv(BaseProteinAlignmentEnv):
    def __init__(self, sequences, true_alignment=None):
        super().__init__(sequences, true_alignment)
        # IntelliAlign parameters
        self.reward_values = {
            'match': 2,       # LL: Letter with same letter
            'mismatch': -2,   # LDL: Letter with different letter
            'gap_letter': -1, # GL: Gap with letter
            'gap_gap': 0      # GG: Gap with gap
        }
        self.gap_costs = {
            'open': -10,     # GOC: Gap opening cost
            'extend': -1      # GEC: Gap extension cost
        }
        self.weights = {
            'sp': 0.6,       # Weight for Sum-of-Pairs
            'tc': 0.4        # Weight for Total Column
        }

    def _calculate_sp_score(self, alignment):
        """Calculate Sum-of-Pairs score with IntelliAlign parameters"""
        total = 0.0
        n_cols = len(alignment[0]) if alignment else 0
        n_seqs = len(alignment)
        
        for col in range(n_cols):
            column = [seq[col] for seq in alignment]
            
            for i in range(n_seqs):
                for j in range(i+1, n_seqs):
                    a, b = column[i], column[j]
                    
                    if a == '-' and b == '-':
                        total += self.reward_values['gap_gap']
                    elif a == '-' or b == '-':
                        total += self.reward_values['gap_letter']
                    elif a == b:
                        total += self.reward_values['match']
                    else:
                        total += self.reward_values['mismatch']
        
        # Normalize by number of columns and pairs
        if n_cols > 0:
            total /= (n_cols * (n_seqs * (n_seqs - 1)) / 2)
        
        return total

    def _calculate_tc_score(self, alignment):
        """Calculate Total Column score (fully conserved columns)"""
        if not alignment:
            return 0.0
            
        n_cols = len(alignment[0])
        tc = 0.0
        
        for col in range(n_cols):
            column = [seq[col] for seq in alignment]
            first = column[0]
            if all(c == first for c in column) and first != '-':
                tc += 1.0
        
        # Normalize by number of columns
        return tc / n_cols

    def _calculate_affine_gap_penalty(self, alignment):
        """Calculate affine gap penalty for the entire alignment"""
        if not alignment:
            return 0.0
            
        total_penalty = 0.0
        n_seqs = len(alignment)
        
        for seq in alignment:
            in_gap = False
            for char in seq:
                if char == '-':
                    if not in_gap:
                        # Gap opening
                        total_penalty += self.gap_costs['open']
                        in_gap = True
                    else:
                        # Gap extension
                        total_penalty += self.gap_costs['extend']
                else:
                    in_gap = False
        
        # Normalize by number of sequences and columns
        n_cols = len(alignment[0])
        return total_penalty / (n_seqs * n_cols)

    def _calculate_reward(self, current_alignment, done):
        """Standardized IntelliAlign reward"""
        if not current_alignment:
            return 0.0
            
        # Calculate components
        sp_score = self._calculate_sp_score(current_alignment)  # Already normalized
        tc_score = self._calculate_tc_score(current_alignment)  # 0-1
        gap_penalty = self._calculate_affine_gap_penalty(current_alignment)
        
        # Weighted combination (SP and TC already comparable)
        reward = (0.6 * sp_score + 0.4 * tc_score + gap_penalty) * 50
        
        # Standard completion bonus
        if done:
            reward += 100.0
            
        return float(reward)

# %% [markdown]
# ### Results

# %% [markdown]
# Production-grade alignment systems often require weeks of training on GPU clusters. This is not a system for production-grade alignments, this is a piece of research investigating how different reward structures affect alignments. Specifically, wether or not SP scores should be the de facto scoring funciton used within the reward structure. Interesting things to explore here include how creating more diverse datasets affects the model.

# %%
# Easy Curriculum Parameters
Config.CURRICULUM_LEVELS = 7
Config.MIN_SEQ_LENGTH = 8
Config.MAX_SEQ_LENGTH = 20
Config.MIN_SEQUENCES = 2
Config.MAX_SEQUENCES = 4
Config.NUM_OF_SEQUENCES = 10  # Replicates per level

Config.INDEL_MODEL_PARAMS = {
        'pow_shape': 1.7,    # Power law shape parameter
        'pow_scale': 100,    # Power law scale parameter
        'min_indel_rate': 0.03,  # Starting indel rate
        'max_indel_rate': 0.03   # Maximum indel rate
    }

easy_curriculum = generate_synthetic_curriculum()
# Out:
# Generated level 1 with 10 alignment blocks
# Generated level 2 with 10 alignment blocks
# Generated level 3 with 10 alignment blocks
# Generated level 4 with 10 alignment blocks
# Generated level 5 with 10 alignment blocks
# Generated level 6 with 10 alignment blocks
# Generated level 7 with 10 alignment blocks

# %%
all_results_on_easy_curriculum = {}
def save_results(results, filename):
            """Save training results (without agent objects)"""
            serializable_results = {}
            for name, data in results.items():
                serializable_results[name] = {
                    'level': data['level'],
                    'scoring_method': data['scoring_method'],
                    'training_rewards': data['training_rewards'],
                    'losses': data['losses'],
                    'eval_results': data['eval_results'],
                }
            
            with open(filename, 'w') as f:
                json.dump(serializable_results, f)

for scoring_method in ['blosum', 'true', 'rlalign', 'msadrl', 'edgealign', 'dpamsa', 'intellialign']:
    try:
        agent, results = train_agent(easy_curriculum, scoring_method)

        all_results_on_easy_curriculum[scoring_method] = {
            'agent': agent,
            'results': results
        }
        
        save_results(results, f"{scoring_method}_model.json")
        
        if agent is not None:
            torch.save(agent.policy_net.state_dict(), f"{scoring_method}_model.pth")
        
        
    except Exception as e:
        print(f"Error processing {scoring_method}: {str(e)}")
        continue
# Out:
# === Starting Level 1-0 (BLOSUM scoring) ===
# Episode 0, Avg Reward: -522.47, Avg Loss: 0.0000, Epsilon: 0.846
# Episode 50, Avg Reward: -334.80, Avg Loss: 19.5044, Epsilon: 0.687
# Episode 100, Avg Reward: 23.42, Avg Loss: 15.7560, Epsilon: 0.558
# Episode 150, Avg Reward: 99.32, Avg Loss: 12.5231, Epsilon: 0.453
# Episode 200, Avg Reward: 111.59, Avg Loss: 11.9338, Epsilon: 0.367
# Episode 250, Avg Reward: 113.40, Avg Loss: 11.3861, Epsilon: 0.298
# Episode 300, Avg Reward: 117.76, Avg Loss: 10.9151, Epsilon: 0.242
# Episode 350, Avg Reward: 116.37, Avg Loss: 10.7731, Epsilon: 0.196
# Early stopping at episode 358 due to no improvement
#
# Example produced alignments:
#   ['QPNLSFHFG-', 'GP-QLSFHFG', 'QPQMSFSFG-']
#   ['QPNLSFHFG', 'GPQLSFHFG', 'QPQMSFSFG']
#   ['QPNLSFHFG-', '-GPQLSFHFG', 'QPQMSFSFG-']
#
# Evaluation for Level 1-0:
#   Average Reward: 122.72 ± 4.02
#   Average SP Score: 2.43 ± 2.09
#   Perfect Match Rate: 0.65
#   Column Accuracy: 0.66
#   Avg Alignment Length: 9.3
#
# === Starting Level 1-1 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 111.60, Avg Loss: 13.8042, Epsilon: 0.846
# Episode 50, Avg Reward: 1.50, Avg Loss: 10.4817, Epsilon: 0.687
# Episode 100, Avg Reward: 88.80, Avg Loss: 10.4930, Epsilon: 0.558
# Episode 150, Avg Reward: 104.77, Avg Loss: 9.7757, Epsilon: 0.453
# Early stopping at episode 180 due to no improvement
#
# Example produced alignments:
#   ['PPPVFGTSV', 'PPPVFGTSV', 'PPPVFGTSV']
#   ['PPPVFGTSV', 'PPPVFGTSV', 'PPPVFGTSV']
#   ['PPPVFGTSV', 'PPPVFGTSV', 'PPPVFGTSV']
#
# Evaluation for Level 1-1:
#   Average Reward: 125.57 ± 3.04
#   Average SP Score: 4.62 ± 1.64
#   Perfect Match Rate: 0.75
#   Column Accuracy: 0.83
#   Avg Alignment Length: 9.2
#
# === Starting Level 1-2 (BLOSUM scoring) ===
# Episode 0, Avg Reward: -100.35, Avg Loss: 8.4387, Epsilon: 0.846
# Episode 50, Avg Reward: 1.55, Avg Loss: 9.8696, Epsilon: 0.687
# Episode 100, Avg Reward: 98.26, Avg Loss: 10.0724, Epsilon: 0.558
# Episode 150, Avg Reward: 98.76, Avg Loss: 9.3742, Epsilon: 0.453
# Episode 200, Avg Reward: 113.22, Avg Loss: 9.6761, Epsilon: 0.367
# Episode 250, Avg Reward: 117.11, Avg Loss: 9.2007, Epsilon: 0.298
# Early stopping at episode 272 due to no improvement
#
# Example produced alignments:
#   ['GHETDAAKS', 'GYDTDAARN', 'GYETEACKS']
#   ['GHETDAAKS', 'GYDTDAARN', 'GYETEACKS']
#   ['GHETDAAKS', 'GYDTDAARN', 'GYETEACKS']
#
# Evaluation for Level 1-2:
#   Average Reward: 125.84 ± 1.63
#   Average SP Score: 3.40 ± 0.37
#   Perfect Match Rate: 0.95
#   Column Accuracy: 0.98
#   Avg Alignment Length: 9.1
#
# === Starting Level 1-3 (BLOSUM scoring) ===
# Episode 0, Avg Reward: -116.78, Avg Loss: 7.8549, Epsilon: 0.846
# Episode 50, Avg Reward: 22.10, Avg Loss: 9.1400, Epsilon: 0.687
# Episode 100, Avg Reward: 66.52, Avg Loss: 9.7859, Epsilon: 0.558
# Early stopping at episode 111 due to no improvement
#
# Example produced alignments:
#   ['HWQGSAKRC', 'HWQGSAKRC', 'HWQGSAKRC']
#   ['HWQGSAKRC', 'HWQGSAKRC', 'HWQGSAKRC']
#   ['HWQGSAKRC', 'HWQGSAKRC', 'HWQGSAKRC']
#
# Evaluation for Level 1-3:
#   Average Reward: 125.50 ± 4.20
#   Average SP Score: 5.87 ± 1.43
#   Perfect Match Rate: 0.90
#   Column Accuracy: 0.92
#   Avg Alignment Length: 9.1
#
# === Starting Level 1-4 (BLOSUM scoring) ===
# Episode 0, Avg Reward: -303.95, Avg Loss: 10.5146, Epsilon: 0.846
# Episode 50, Avg Reward: 20.99, Avg Loss: 9.3028, Epsilon: 0.687
# Episode 100, Avg Reward: 89.54, Avg Loss: 9.1051, Epsilon: 0.558
# Episode 150, Avg Reward: 106.64, Avg Loss: 9.0198, Epsilon: 0.453
# Early stopping at episode 199 due to no improvement
#
# Example produced alignments:
#   ['TMPKKKVKN', 'IMPQQKVKY', 'IMPKKKVRY']
#   ['TMPKKKVKN', 'IMPQQKVKY', 'IMPKKKVRY']
#   ['TMPKKKVKN', 'IMPQQKVKY', 'IMPKKKVRY']
#
# Evaluation for Level 1-4:
#   Average Reward: 125.30 ± 1.27
#   Average SP Score: 2.94 ± 1.03
#   Perfect Match Rate: 0.85
#   Column Accuracy: 0.91
#   Avg Alignment Length: 9.2
#
# === Starting Level 1-5 (BLOSUM scoring) ===
# Episode 0, Avg Reward: -423.52, Avg Loss: 8.6187, Epsilon: 0.846
# Episode 50, Avg Reward: 59.42, Avg Loss: 9.2909, Epsilon: 0.687
# Episode 100, Avg Reward: 84.55, Avg Loss: 9.5366, Epsilon: 0.558
# Episode 150, Avg Reward: 94.42, Avg Loss: 9.2455, Epsilon: 0.453
# Episode 200, Avg Reward: 112.29, Avg Loss: 8.8842, Epsilon: 0.367
# Early stopping at episode 225 due to no improvement
#
# Example produced alignments:
#   ['DRFPTN-VFS', 'DRFPMN-VFS', 'DKFPMRVFA-']
#   ['DRFPTNVFS-', 'DRFPMN-VFS', 'DKFPMRVFA-']
#   ['DRF-PTNVFS', 'DRFPMNVFS-', 'DKFPMRVFA-']
#
# Evaluation for Level 1-5:
#   Average Reward: 126.39 ± 3.40
#   Average SP Score: 3.38 ± 1.38
#   Perfect Match Rate: 0.75
#   Column Accuracy: 0.87
#   Avg Alignment Length: 9.2
#
# === Starting Level 1-6 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 110.33, Avg Loss: 10.6833, Epsilon: 0.846
# Episode 50, Avg Reward: 49.63, Avg Loss: 9.0205, Epsilon: 0.687
# Episode 100, Avg Reward: 106.31, Avg Loss: 8.6625, Epsilon: 0.558
# Episode 150, Avg Reward: 101.61, Avg Loss: 8.5915, Epsilon: 0.453
# Episode 200, Avg Reward: 116.23, Avg Loss: 8.9699, Epsilon: 0.367
# Episode 250, Avg Reward: 116.59, Avg Loss: 8.6894, Epsilon: 0.298
# Episode 300, Avg Reward: 118.88, Avg Loss: 9.0055, Epsilon: 0.242
# Early stopping at episode 311 due to no improvement
#
# Example produced alignments:
#   ['FFRDHPVLE', 'FFRDHPVVQ', 'FFRDHPVLE']
#   ['FFRDHPVLE', 'FFRDHPVVQ', 'FFRDHPVLE']
#   ['FFRDHPVLE', 'FFRDHPVVQ', 'FFRDHPVLE']
#
# Evaluation for Level 1-6:
#   Average Reward: 125.79 ± 2.71
#   Average SP Score: 4.43 ± 1.67
#   Perfect Match Rate: 0.80
#   Column Accuracy: 0.86
#   Avg Alignment Length: 9.2
#
# === Starting Level 1-7 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 117.22, Avg Loss: 5.3596, Epsilon: 0.846
# Episode 50, Avg Reward: 8.29, Avg Loss: 9.0767, Epsilon: 0.687
# Episode 100, Avg Reward: 83.59, Avg Loss: 9.0582, Epsilon: 0.558
# Early stopping at episode 129 due to no improvement
#
# Example produced alignments:
#   ['EHIAKNAKE', 'EHIARNAKE', 'EHIARNAKE']
#   ['EHIAKNAKE', 'EHIARNAKE', 'EHIARNAKE']
#   ['EHIAKNAKE', 'EHIARNAKE', 'EHIARNAKE']
#
# Evaluation for Level 1-7:
#   Average Reward: 125.35 ± 3.08
#   Average SP Score: 4.32 ± 1.44
#   Perfect Match Rate: 0.85
#   Column Accuracy: 0.88
#   Avg Alignment Length: 9.2
#
# === Starting Level 1-8 (BLOSUM scoring) ===
# Episode 0, Avg Reward: -110.20, Avg Loss: 10.1514, Epsilon: 0.846
# Episode 50, Avg Reward: -1.31, Avg Loss: 8.2986, Epsilon: 0.687
# Episode 100, Avg Reward: 90.05, Avg Loss: 8.7361, Epsilon: 0.558
# Episode 150, Avg Reward: 111.35, Avg Loss: 8.7880, Epsilon: 0.453
# Episode 200, Avg Reward: 111.53, Avg Loss: 8.6093, Epsilon: 0.367
# Early stopping at episode 234 due to no improvement
#
# Example produced alignments:
#   ['MCYGFVMWW-', 'MCYGFVMRW-', 'MCYGF-VMWW']
#   ['MCYGFVMWW', 'MCYGFVMRW', 'MCYGFVMWW']
#   ['MCYGFVMWW', 'MCYGFVMRW', 'MCYGFVMWW']
#
# Evaluation for Level 1-8:
#   Average Reward: 127.87 ± 3.46
#   Average SP Score: 5.67 ± 0.85
#   Perfect Match Rate: 0.80
#   Column Accuracy: 0.95
#   Avg Alignment Length: 9.2
#
# === Starting Level 1-9 (BLOSUM scoring) ===
# Episode 0, Avg Reward: -100.40, Avg Loss: 8.1378, Epsilon: 0.846
# Episode 50, Avg Reward: 33.15, Avg Loss: 8.9973, Epsilon: 0.687
# Episode 100, Avg Reward: 99.74, Avg Loss: 9.1144, Epsilon: 0.558
# Episode 150, Avg Reward: 103.18, Avg Loss: 9.0358, Epsilon: 0.453
# Episode 200, Avg Reward: 110.72, Avg Loss: 8.5140, Epsilon: 0.367
# Early stopping at episode 212 due to no improvement
#
# Example produced alignments:
#   ['RLYMTAIFY', 'RLYMTAILY', 'REFMTAIFY']
#   ['RLYMTAIFY', 'RLYMTAILY', 'REFMTAIFY']
#   ['RLYMTAIFY', 'RLYMTAILY', 'REFMTAIFY']
#
# Evaluation for Level 1-9:
#   Average Reward: 124.82 ± 4.35
#   Average SP Score: 3.69 ± 0.92
#   Perfect Match Rate: 0.90
#   Column Accuracy: 0.93
#   Avg Alignment Length: 9.1
#
# === Starting Level 2-0 (BLOSUM scoring) ===
# Reinitializing agent due to state size change (220 -> 285)
# Episode 0, Avg Reward: -216.23, Avg Loss: 0.0000, Epsilon: 0.698
# Episode 50, Avg Reward: -528.51, Avg Loss: 23.2986, Epsilon: 0.598
# Episode 100, Avg Reward: -186.08, Avg Loss: 18.8675, Epsilon: 0.513
# Episode 150, Avg Reward: -42.11, Avg Loss: 15.0821, Epsilon: 0.439
# Episode 200, Avg Reward: 90.97, Avg Loss: 12.3984, Epsilon: 0.377
# Episode 250, Avg Reward: 108.71, Avg Loss: 11.2932, Epsilon: 0.323
# Episode 300, Avg Reward: 112.50, Avg Loss: 10.4125, Epsilon: 0.277
# Episode 350, Avg Reward: 115.61, Avg Loss: 10.7992, Epsilon: 0.237
# Episode 400, Avg Reward: 115.81, Avg Loss: 9.2701, Epsilon: 0.203
# Early stopping at episode 445 due to no improvement
#
# Example produced alignments:
#   ['FFYWLEHYHSF-', 'FFYWREHAYKSF', 'FFYWLEHYHSF-', 'FFYWLEHYHSF-']
#   ['FFYWLEHYHSF-', 'FFYWREHAYKSF', 'FFYWLEHYHSF-', 'FFYWLEHYHSF-']
#   ['FFYWLEHYHSF-', 'FFYWREHAYKSF', 'FFYWLEHYHSF-', 'FFYWLEHYHSF-']
#
# Evaluation for Level 2-0:
#   Average Reward: 123.27 ± 2.40
#   Average SP Score: 4.42 ± 0.71
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.56
#   Avg Alignment Length: 12.1
#
# === Starting Level 2-1 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 101.78, Avg Loss: 10.8780, Epsilon: 0.698
# Episode 50, Avg Reward: 92.91, Avg Loss: 9.0233, Epsilon: 0.598
# Episode 100, Avg Reward: 100.48, Avg Loss: 8.8721, Epsilon: 0.513
# Early stopping at episode 144 due to no improvement
#
# Example produced alignments:
#   ['VQQRNKM-PAMT--', 'VQRRNKMWFGPAMK', 'VQRRNKMTTMA---', 'VQRRNKMPAMK---']
#   ['VQQRNKMPAMT---', 'VQRRNKMWFGPAMK', 'VQRRNKMTTMA---', 'VQRRNKMPAMK---']
#   ['VQQRNKMPAMT---', 'VQRRNKMWFGPAMK', 'VQRRNKMTTMA---', 'VQRRNKMPAMK---']
#
# Evaluation for Level 2-1:
#   Average Reward: 123.48 ± 5.25
#   Average SP Score: 1.99 ± 0.47
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.45
#   Avg Alignment Length: 14.1
#
# === Starting Level 2-2 (BLOSUM scoring) ===
# Episode 0, Avg Reward: -113.57, Avg Loss: 5.5188, Epsilon: 0.698
# Episode 50, Avg Reward: 64.99, Avg Loss: 8.2958, Epsilon: 0.598
# Episode 100, Avg Reward: 95.21, Avg Loss: 8.2657, Epsilon: 0.513
# Episode 150, Avg Reward: 106.32, Avg Loss: 8.0649, Epsilon: 0.439
# Episode 200, Avg Reward: 108.16, Avg Loss: 8.2013, Epsilon: 0.377
# Early stopping at episode 240 due to no improvement
#
# Example produced alignments:
#   ['IITGIWSLITI', 'IITGIWSVMTI', 'IITGIWSVITI', 'VITGIWSVITI']
#   ['IITGIWSLITI', 'IITGIWSVMTI', 'IITGIWSVITI', 'VITGIWSVITI']
#   ['IITGIWSLITI', 'IITGIWSVMTI', 'IITGIWSVITI', 'VITGIWSVITI']
#
# Evaluation for Level 2-2:
#   Average Reward: 120.57 ± 1.19
#   Average SP Score: 4.26 ± 1.27
#   Perfect Match Rate: 0.90
#   Column Accuracy: 0.92
#   Avg Alignment Length: 11.2
#
# === Starting Level 2-3 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 97.47, Avg Loss: 9.3895, Epsilon: 0.698
# Episode 50, Avg Reward: 44.80, Avg Loss: 8.1126, Epsilon: 0.598
# Episode 100, Avg Reward: 97.70, Avg Loss: 8.2499, Epsilon: 0.513
# Early stopping at episode 103 due to no improvement
#
# Example produced alignments:
#   ['WYHEWRPHDYI', 'RPHSYI-----', 'WWQEWRPSDHI', 'WYHEWRPHDYI']
#   ['WYHEWRPHDYI-', '-RPHSYI-----', '-WWQEWRPSDHI', '-WYHEWRPHDYI']
#   ['WYHEWRPHDYI', 'RPHSYI-----', 'WWQEWRPSDHI', 'WYHEWRPHDYI']
#
# Evaluation for Level 2-3:
#   Average Reward: 113.57 ± 2.53
#   Average SP Score: 2.23 ± 0.69
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.00
#   Avg Alignment Length: 11.1
#
# === Starting Level 2-4 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 128.94, Avg Loss: 6.8422, Epsilon: 0.698
# Episode 50, Avg Reward: 53.00, Avg Loss: 8.4012, Epsilon: 0.598
# Episode 100, Avg Reward: 94.69, Avg Loss: 7.9144, Epsilon: 0.513
# Episode 150, Avg Reward: 102.21, Avg Loss: 8.1435, Epsilon: 0.439
# Episode 200, Avg Reward: 110.54, Avg Loss: 7.5356, Epsilon: 0.377
# Episode 250, Avg Reward: 111.07, Avg Loss: 7.5771, Epsilon: 0.323
# Early stopping at episode 274 due to no improvement
#
# Example produced alignments:
#   ['SWFAAHEKHEG-', 'K-YFAAHQKHEG', 'R-YFAAHQKHEG', 'SYFAAHQKHEG-']
#   ['SWFAAHEKHEG', 'KYFAAHQKHEG', 'RYFAAHQKHEG', 'SYFAAHQKHEG']
#   ['SWFAAHEKHEG', 'KYFAAHQKHEG', 'RYFAAHQKHEG', 'SYFAAHQKHEG']
#
# Evaluation for Level 2-4:
#   Average Reward: 120.03 ± 1.76
#   Average SP Score: 4.44 ± 1.29
#   Perfect Match Rate: 0.85
#   Column Accuracy: 0.89
#   Avg Alignment Length: 11.2
#
# === Starting Level 2-5 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 113.97, Avg Loss: 5.9758, Epsilon: 0.698
# Episode 50, Avg Reward: 30.18, Avg Loss: 7.8623, Epsilon: 0.598
# Episode 100, Avg Reward: 93.49, Avg Loss: 8.1610, Epsilon: 0.513
# Episode 150, Avg Reward: 104.05, Avg Loss: 7.5211, Epsilon: 0.439
# Episode 200, Avg Reward: 107.47, Avg Loss: 7.6318, Epsilon: 0.377
# Episode 250, Avg Reward: 111.28, Avg Loss: 7.3953, Epsilon: 0.323
# Early stopping at episode 294 due to no improvement
#
# Example produced alignments:
#   ['HTDNKNKIWSG', 'HTDYRSKIYMG', 'HTDYRNKIWSG', 'HTDYRNKIWSG']
#   ['HTDNKNKIWSG', 'HTDYRSKIYMG', 'HTDYRNKIWSG', 'HTDYRNKIWSG']
#   ['HTDNKNKIWSG', 'HTDYRSKIYMG', 'HTDYRNKIWSG', 'HTDYRNKIWSG']
#
# Evaluation for Level 2-5:
#   Average Reward: 120.36 ± 3.09
#   Average SP Score: 4.15 ± 1.17
#   Perfect Match Rate: 0.80
#   Column Accuracy: 0.90
#   Avg Alignment Length: 11.2
#
# === Starting Level 2-6 (BLOSUM scoring) ===
# Episode 0, Avg Reward: -818.96, Avg Loss: 7.9720, Epsilon: 0.698
# Episode 50, Avg Reward: 62.78, Avg Loss: 7.5179, Epsilon: 0.598
# Episode 100, Avg Reward: 97.30, Avg Loss: 7.4881, Epsilon: 0.513
# Episode 150, Avg Reward: 104.74, Avg Loss: 8.0223, Epsilon: 0.439
# Episode 200, Avg Reward: 108.49, Avg Loss: 7.7319, Epsilon: 0.377
# Early stopping at episode 237 due to no improvement
#
# Example produced alignments:
#   ['CDVQPSQNVAQ', 'CDVQPSQNMAQ', 'CDVQPSTNVAQ', 'GDVQPSQNVAQ']
#   ['CDVQPSQNVAQ', 'CDVQPSQNMAQ', 'CDVQPSTNVAQ', 'GDVQPSQNVAQ']
#   ['CDVQPSQNVAQ', 'CDVQPSQNMAQ', 'CDVQPSTNVAQ', 'GDVQPSQNVAQ']
#
# Evaluation for Level 2-6:
#   Average Reward: 120.75 ± 1.40
#   Average SP Score: 4.25 ± 0.49
#   Perfect Match Rate: 0.90
#   Column Accuracy: 0.97
#   Avg Alignment Length: 11.1
#
# === Starting Level 2-7 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 111.23, Avg Loss: 9.3215, Epsilon: 0.698
# Episode 50, Avg Reward: 77.57, Avg Loss: 7.3903, Epsilon: 0.598
# Episode 100, Avg Reward: 89.21, Avg Loss: 7.4226, Epsilon: 0.513
# Episode 150, Avg Reward: 101.07, Avg Loss: 7.4161, Epsilon: 0.439
# Episode 200, Avg Reward: 104.96, Avg Loss: 7.3893, Epsilon: 0.377
# Episode 250, Avg Reward: 109.72, Avg Loss: 7.0792, Epsilon: 0.323
# Episode 300, Avg Reward: 109.49, Avg Loss: 7.3556, Epsilon: 0.277
# Early stopping at episode 316 due to no improvement
#
# Example produced alignments:
#   ['TLATIFDTQPY', 'TLATMFDTRPY', 'TLATVFDTRPY', 'YLATIFDTHPY']
#   ['TL-ATIFDTQPY', 'TL-ATMFDTRPY', 'TLATVFDTRPY-', 'YL-ATIFDTHPY']
#   ['TLATIFDTQPY', 'TLATMFDTRPY', 'TLATVFDTRPY', 'YLATIFDTHPY']
#
# Evaluation for Level 2-7:
#   Average Reward: 120.28 ± 2.47
#   Average SP Score: 4.21 ± 0.73
#   Perfect Match Rate: 0.90
#   Column Accuracy: 0.95
#   Avg Alignment Length: 11.1
#
# === Starting Level 2-8 (BLOSUM scoring) ===
# Episode 0, Avg Reward: -205.54, Avg Loss: 5.6805, Epsilon: 0.698
# Episode 50, Avg Reward: 67.33, Avg Loss: 7.3086, Epsilon: 0.598
# Episode 100, Avg Reward: 101.15, Avg Loss: 7.2818, Epsilon: 0.513
# Episode 150, Avg Reward: 90.06, Avg Loss: 7.4894, Epsilon: 0.439
# Episode 200, Avg Reward: 106.26, Avg Loss: 7.5537, Epsilon: 0.377
# Episode 250, Avg Reward: 109.72, Avg Loss: 7.2398, Epsilon: 0.323
# Episode 300, Avg Reward: 112.35, Avg Loss: 7.4868, Epsilon: 0.277
# Early stopping at episode 312 due to no improvement
#
# Example produced alignments:
#   ['FWMDYQLRSGL', 'FWMEYQLRNGL', 'FWMEYQLRSGL', 'FWMEFQMRGGL']
#   ['FWMDYQLRSGL', 'FWMEYQLRNGL', 'FWMEYQLRSGL', 'FWMEFQMRGGL']
#   ['FWMDYQLRSGL', 'FWMEYQLRNGL', 'FWMEYQLRSGL', 'FWMEFQMRGGL']
#
# Evaluation for Level 2-8:
#   Average Reward: 120.29 ± 1.74
#   Average SP Score: 4.54 ± 1.25
#   Perfect Match Rate: 0.90
#   Column Accuracy: 0.91
#   Avg Alignment Length: 11.1
#
# === Starting Level 2-9 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 93.92, Avg Loss: 7.3624, Epsilon: 0.698
# Episode 50, Avg Reward: 80.81, Avg Loss: 7.2756, Epsilon: 0.598
# Episode 100, Avg Reward: 81.32, Avg Loss: 7.2268, Epsilon: 0.513
# Episode 150, Avg Reward: 99.29, Avg Loss: 6.9923, Epsilon: 0.439
# Episode 200, Avg Reward: 104.33, Avg Loss: 7.2580, Epsilon: 0.377
# Episode 250, Avg Reward: 106.73, Avg Loss: 7.1280, Epsilon: 0.323
# Early stopping at episode 264 due to no improvement
#
# Example produced alignments:
#   ['ICKFEAPPNY-', 'ICKFEACPPNY', 'ICKFENCTPHY', 'ICNY-------']
#   ['ICKFEAPPNY-', 'ICKFEACPPNY', 'ICKFENCTPHY', 'ICNY-------']
#   ['ICKFEAPPNY-', 'ICKFEACPPNY', 'ICKFENCTPHY', 'ICNY-------']
#
# Evaluation for Level 2-9:
#   Average Reward: 117.80 ± 0.38
#   Average SP Score: 1.98 ± 0.08
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.45
#   Avg Alignment Length: 11.1
#
# === Starting Level 3-0 (BLOSUM scoring) ===
# Reinitializing agent due to state size change (285 -> 155)
# Episode 0, Avg Reward: 118.70, Avg Loss: 0.0000, Epsilon: 0.549
# Episode 50, Avg Reward: 138.52, Avg Loss: 5.9585, Epsilon: 0.486
# Episode 100, Avg Reward: 161.28, Avg Loss: 7.5900, Epsilon: 0.431
# Episode 150, Avg Reward: 177.34, Avg Loss: 8.0767, Epsilon: 0.382
# Episode 200, Avg Reward: 178.41, Avg Loss: 8.2174, Epsilon: 0.339
# Early stopping at episode 206 due to no improvement
#
# Example produced alignments:
#   ['ATGLHQLLSSRCV', 'KTGLYRLLSIRCV']
#   ['ATGLHQLLSSRCV', 'KTGLYRLLSIRCV']
#   ['ATGLHQLLSSRCV', 'KTGLYRLLSIRCV']
#
# Evaluation for Level 3-0:
#   Average Reward: 256.82 ± 19.34
#   Average SP Score: 3.13 ± 1.18
#   Perfect Match Rate: 0.90
#   Column Accuracy: 0.96
#   Avg Alignment Length: 13.1
#
# === Starting Level 3-1 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 68.40, Avg Loss: 9.7159, Epsilon: 0.549
# Episode 50, Avg Reward: 167.71, Avg Loss: 8.0566, Epsilon: 0.486
# Episode 100, Avg Reward: 200.38, Avg Loss: 7.5642, Epsilon: 0.431
# Episode 150, Avg Reward: 233.44, Avg Loss: 7.6502, Epsilon: 0.382
# Episode 200, Avg Reward: 261.72, Avg Loss: 7.8499, Epsilon: 0.339
# Early stopping at episode 239 due to no improvement
#
# Example produced alignments:
#   ['IAMFFAWWYEMCM--------', 'VAMFFAWWYSRFEPWHNEMCM']
#   ['IAMFFAWWYEMCM---------', '-VAMFFAWWYSRFEPWHNEMCM']
#   ['IAMFFAWWYEMCM--------', 'VAMFFAWWYSRFEPWHNEMCM']
#
# Evaluation for Level 3-1:
#   Average Reward: 455.48 ± 57.18
#   Average SP Score: 1.96 ± 0.58
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.59
#   Avg Alignment Length: 21.1
#
# === Starting Level 3-2 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 109.15, Avg Loss: 8.9141, Epsilon: 0.549
# Episode 50, Avg Reward: 146.12, Avg Loss: 8.0561, Epsilon: 0.486
# Episode 100, Avg Reward: 160.13, Avg Loss: 8.4421, Epsilon: 0.431
# Episode 150, Avg Reward: 178.64, Avg Loss: 9.4149, Epsilon: 0.382
# Episode 200, Avg Reward: 181.89, Avg Loss: 9.5374, Epsilon: 0.339
# Episode 250, Avg Reward: 201.85, Avg Loss: 9.6933, Epsilon: 0.300
# Episode 300, Avg Reward: 190.72, Avg Loss: 9.5304, Epsilon: 0.266
# Early stopping at episode 306 due to no improvement
#
# Example produced alignments:
#   ['SQILEMTKQMSLM', 'SQIIEVTKQMSLM']
#   ['SQILEMTKQMSLM', 'SQIIEVTKQMSLM']
#   ['SQILEMTKQMSLM', 'SQIIEVTKQMSLM']
#
# Evaluation for Level 3-2:
#   Average Reward: 258.45 ± 0.00
#   Average SP Score: 4.15 ± 0.00
#   Perfect Match Rate: 1.00
#   Column Accuracy: 1.00
#   Avg Alignment Length: 13.0
#
# === Starting Level 3-3 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 152.35, Avg Loss: 9.6322, Epsilon: 0.549
# Episode 50, Avg Reward: 147.82, Avg Loss: 9.9822, Epsilon: 0.486
# Episode 100, Avg Reward: 151.02, Avg Loss: 9.7294, Epsilon: 0.431
# Early stopping at episode 113 due to no improvement
#
# Example produced alignments:
#   ['GKSFCNMTRAPMY', 'EKSFCNMTRAPMY']
#   ['GKSFCNMTRAPMY', 'EKSFCNMTRAPMY']
#   ['GKSFCNMTRAPMY', 'EKSFCNMTRAPMY']
#
# Evaluation for Level 3-3:
#   Average Reward: 256.31 ± 11.49
#   Average SP Score: 4.76 ± 1.39
#   Perfect Match Rate: 0.95
#   Column Accuracy: 0.96
#   Avg Alignment Length: 13.1
#
# === Starting Level 3-4 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 179.85, Avg Loss: 8.9661, Epsilon: 0.549
# Episode 50, Avg Reward: 146.08, Avg Loss: 9.4623, Epsilon: 0.486
# Episode 100, Avg Reward: 150.81, Avg Loss: 9.3919, Epsilon: 0.431
# Episode 150, Avg Reward: 160.33, Avg Loss: 9.4231, Epsilon: 0.382
# Episode 200, Avg Reward: 155.74, Avg Loss: 9.3589, Epsilon: 0.339
# Early stopping at episode 216 due to no improvement
#
# Example produced alignments:
#   ['QWWPLGHLRDMID', 'WWPLGHLSDAID-']
#   ['QWWPLGHLRDMID', 'WWPLGHLSDAID-']
#   ['QWWPLGHLRDMID', 'WWPLGHLSDAID-']
#
# Evaluation for Level 3-4:
#   Average Reward: 157.82 ± 3.08
#   Average SP Score: -1.26 ± 0.18
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.08
#   Avg Alignment Length: 13.1
#
# === Starting Level 3-5 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 258.75, Avg Loss: 8.5568, Epsilon: 0.549
# Episode 50, Avg Reward: 155.24, Avg Loss: 9.7826, Epsilon: 0.486
# Episode 100, Avg Reward: 162.72, Avg Loss: 9.6750, Epsilon: 0.431
# Episode 150, Avg Reward: 171.45, Avg Loss: 9.5363, Epsilon: 0.382
# Episode 200, Avg Reward: 171.53, Avg Loss: 9.6388, Epsilon: 0.339
# Episode 250, Avg Reward: 195.91, Avg Loss: 9.6668, Epsilon: 0.300
# Episode 300, Avg Reward: 199.97, Avg Loss: 9.7936, Epsilon: 0.266
# Early stopping at episode 305 due to no improvement
#
# Example produced alignments:
#   ['KDGLWSHFCGTTC', 'KDGLWSLYCGETC']
#   ['KDGLWSHFCGTTC', 'KDGLWSLYCGETC']
#   ['KDGLWSHFCGTTC', 'KDGLWSLYCGETC']
#
# Evaluation for Level 3-5:
#   Average Reward: 261.05 ± 14.38
#   Average SP Score: 4.31 ± 1.32
#   Perfect Match Rate: 0.80
#   Column Accuracy: 0.92
#   Avg Alignment Length: 13.2
#
# === Starting Level 3-6 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 216.30, Avg Loss: 9.8959, Epsilon: 0.549
# Episode 50, Avg Reward: 174.68, Avg Loss: 9.8227, Epsilon: 0.486
# Episode 100, Avg Reward: 179.22, Avg Loss: 9.7158, Epsilon: 0.431
# Early stopping at episode 116 due to no improvement
#
# Example produced alignments:
#   ['CQESWTCTDRQLQ', 'CQEWWTCTDEQLQ']
#   ['CQESWTCTDRQLQ', 'CQEWWTCTDEQLQ']
#   ['CQESWTCTDRQLQ', 'CQEWWTCTDEQLQ']
#
# Evaluation for Level 3-6:
#   Average Reward: 258.47 ± 4.62
#   Average SP Score: 4.70 ± 1.15
#   Perfect Match Rate: 0.90
#   Column Accuracy: 0.95
#   Avg Alignment Length: 13.1
#
# === Starting Level 3-7 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 214.20, Avg Loss: 8.4047, Epsilon: 0.549
# Episode 50, Avg Reward: 157.34, Avg Loss: 9.8916, Epsilon: 0.486
# Episode 100, Avg Reward: 164.26, Avg Loss: 9.7479, Epsilon: 0.431
# Early stopping at episode 137 due to no improvement
#
# Example produced alignments:
#   ['CMPGMGYLHYEWE', 'CMDGMGYLHYECE']
#   ['CMPGMGYLHYEWE', 'CMDGMGYLHYECE']
#   ['CMPGMGYLHYEWE', 'CMDGMGYLHYECE']
#
# Evaluation for Level 3-7:
#   Average Reward: 255.06 ± 25.78
#   Average SP Score: 4.22 ± 1.84
#   Perfect Match Rate: 0.85
#   Column Accuracy: 0.91
#   Avg Alignment Length: 13.2
#
# === Starting Level 3-8 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 158.75, Avg Loss: 9.9924, Epsilon: 0.549
# Episode 50, Avg Reward: 151.74, Avg Loss: 9.8042, Epsilon: 0.486
# Episode 100, Avg Reward: 163.89, Avg Loss: 10.0318, Epsilon: 0.431
# Episode 150, Avg Reward: 183.04, Avg Loss: 9.8866, Epsilon: 0.382
# Early stopping at episode 197 due to no improvement
#
# Example produced alignments:
#   ['FWVFPYDHFGSRC-', 'FWLF-PYDHFGSQC']
#   ['F-WVFPYDHFGSRC', 'FWLFPYDHFGSQC-']
#   ['FWVFPYDHFGSRC', 'FWLFPYDHFGSQC']
#
# Evaluation for Level 3-8:
#   Average Reward: 249.52 ± 25.28
#   Average SP Score: 4.95 ± 2.51
#   Perfect Match Rate: 0.85
#   Column Accuracy: 0.88
#   Avg Alignment Length: 13.2
#
# === Starting Level 3-9 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 112.90, Avg Loss: 10.6217, Epsilon: 0.549
# Episode 50, Avg Reward: 147.09, Avg Loss: 9.7714, Epsilon: 0.486
# Episode 100, Avg Reward: 164.13, Avg Loss: 10.0555, Epsilon: 0.431
# Episode 150, Avg Reward: 162.46, Avg Loss: 10.2849, Epsilon: 0.382
# Episode 200, Avg Reward: 179.90, Avg Loss: 10.2232, Epsilon: 0.339
# Early stopping at episode 233 due to no improvement
#
# Example produced alignments:
#   ['MSGMFYIGSNKPI', 'MSGMFYIGKNQPI']
#   ['MSGMFYIGSNKPI', 'MSGMFYIGKNQPI']
#   ['MSGMFYIGSNKPI', 'MSGMFYIGKNQPI']
#
# Evaluation for Level 3-9:
#   Average Reward: 252.27 ± 24.59
#   Average SP Score: 4.16 ± 1.62
#   Perfect Match Rate: 0.90
#   Column Accuracy: 0.92
#   Avg Alignment Length: 13.1
#
# === Starting Level 4-0 (BLOSUM scoring) ===
# Reinitializing agent due to state size change (155 -> 220)
# Episode 0, Avg Reward: -928.08, Avg Loss: 0.0000, Epsilon: 0.399
# Episode 50, Avg Reward: -373.45, Avg Loss: 19.7435, Epsilon: 0.362
# Episode 100, Avg Reward: -80.10, Avg Loss: 13.7248, Epsilon: 0.329
# Episode 150, Avg Reward: 132.71, Avg Loss: 11.5339, Epsilon: 0.299
# Episode 200, Avg Reward: 132.19, Avg Loss: 10.5631, Epsilon: 0.271
# Early stopping at episode 211 due to no improvement
#
# Example produced alignments:
#   ['NYFMKLFELPVQQW', 'NHFMRLFEFPTQQW', 'NHFMKLFKLPVQEW']
#   ['NYFMKLFELPVQQW', 'NHFMRLFEFPTQQW', 'NHFMKLFKLPVQEW']
#   ['NYFMKLFELPVQQW', 'NHFMRLFEFPTQQW', 'NHFMKLFKLPVQEW']
#
# Evaluation for Level 4-0:
#   Average Reward: 162.79 ± 2.50
#   Average SP Score: 4.47 ± 0.75
#   Perfect Match Rate: 0.95
#   Column Accuracy: 0.97
#   Avg Alignment Length: 14.1
#
# === Starting Level 4-1 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 132.73, Avg Loss: 10.3806, Epsilon: 0.399
# Episode 50, Avg Reward: 122.28, Avg Loss: 9.5075, Epsilon: 0.362
# Episode 100, Avg Reward: 122.14, Avg Loss: 9.1690, Epsilon: 0.329
# Episode 150, Avg Reward: -18.65, Avg Loss: 8.9101, Epsilon: 0.299
# Early stopping at episode 199 due to no improvement
#
# Example produced alignments:
#   ['IGAKEQVKYAACSH', 'IGYKDQVKFAACSH', 'IGFKVQVKFAACSH']
#   ['IGAKEQVKYAACSH', 'IGYKDQVKFAACSH', 'IGFKVQVKFAACSH']
#   ['IGAKEQVKYAACSH', 'IGYKDQVKFAACSH', 'IGFKVQVKFAACSH']
#
# Evaluation for Level 4-1:
#   Average Reward: 164.05 ± 2.78
#   Average SP Score: 3.93 ± 0.97
#   Perfect Match Rate: 0.85
#   Column Accuracy: 0.93
#   Avg Alignment Length: 14.2
#
# === Starting Level 4-2 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 170.72, Avg Loss: 5.4801, Epsilon: 0.399
# Episode 50, Avg Reward: 116.64, Avg Loss: 8.6555, Epsilon: 0.362
# Episode 100, Avg Reward: 131.51, Avg Loss: 8.0049, Epsilon: 0.329
# Episode 150, Avg Reward: 128.38, Avg Loss: 8.2784, Epsilon: 0.299
# Episode 200, Avg Reward: 137.02, Avg Loss: 8.2865, Epsilon: 0.271
# Episode 250, Avg Reward: 143.87, Avg Loss: 8.4391, Epsilon: 0.246
# Early stopping at episode 261 due to no improvement
#
# Example produced alignments:
#   ['PKRTKGDLHLMWFE-', 'PKGQSGDLHLMWF-E', 'PKRQSGDLQLMWFE-']
#   ['PKRTKGDLHLMWFE', 'PKGQSGDLHLMWFE', 'PKRQSGDLQLMWFE']
#   ['PKRTKGDLHLMWFE', 'PKGQSGDLHLMWFE', 'PKRQSGDLQLMWFE']
#
# Evaluation for Level 4-2:
#   Average Reward: 161.96 ± 12.12
#   Average SP Score: 3.93 ± 1.29
#   Perfect Match Rate: 0.75
#   Column Accuracy: 0.87
#   Avg Alignment Length: 14.2
#
# === Starting Level 4-3 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 84.25, Avg Loss: 10.9426, Epsilon: 0.399
# Episode 50, Avg Reward: 122.44, Avg Loss: 8.2921, Epsilon: 0.362
# Episode 100, Avg Reward: 123.50, Avg Loss: 8.2386, Epsilon: 0.329
# Early stopping at episode 134 due to no improvement
#
# Example produced alignments:
#   ['ELYMGINQTSKTQE', 'HLYMGINQTSKTQE', 'ELHKGINQTSKTQE']
#   ['ELYMGINQTSKTQE', 'HLYMGINQTSKTQE', 'ELHKGINQTSKTQE']
#   ['ELYMGINQTSKTQE', 'HLYMGINQTSKTQE', 'ELHKGINQTSKTQE']
#
# Evaluation for Level 4-3:
#   Average Reward: 162.72 ± 2.66
#   Average SP Score: 4.02 ± 0.86
#   Perfect Match Rate: 0.90
#   Column Accuracy: 0.94
#   Avg Alignment Length: 14.1
#
# === Starting Level 4-4 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 94.32, Avg Loss: 7.1825, Epsilon: 0.399
# Episode 50, Avg Reward: 107.28, Avg Loss: 7.6683, Epsilon: 0.362
# Episode 100, Avg Reward: 103.34, Avg Loss: 7.5545, Epsilon: 0.329
# Early stopping at episode 113 due to no improvement
#
# Example produced alignments:
#   ['PSVFIQSISWSTWL--', 'YIISVFIQSISWSTWL', 'PSVFVQSILWSTWL--']
#   ['P-SVFIQSI-SWSTWL-', 'Y-IISVFIQSISWSTWL', 'PSVFVQSIL-WSTWL--']
#   ['PSVFIQSISWSTWL--', 'YIISVFIQSISWSTWL', 'PSVFVQSILWSTWL--']
#
# Evaluation for Level 4-4:
#   Average Reward: 119.33 ± 3.92
#   Average SP Score: 0.70 ± 0.49
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.00
#   Avg Alignment Length: 16.1
#
# === Starting Level 4-5 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 113.50, Avg Loss: 8.4082, Epsilon: 0.399
# Episode 50, Avg Reward: 123.76, Avg Loss: 8.0374, Epsilon: 0.362
# Episode 100, Avg Reward: 127.95, Avg Loss: 7.5672, Epsilon: 0.329
# Episode 150, Avg Reward: 127.73, Avg Loss: 7.8422, Epsilon: 0.299
# Early stopping at episode 171 due to no improvement
#
# Example produced alignments:
#   ['SHKFGNLATQVHSF', 'SHKFGNLATQVHSF', 'RFKFGNLGTQVHSC']
#   ['SHKFGNLATQVHSF', 'SHKFGNLATQVHSF', 'RFKFGNLGTQVHSC']
#   ['SHKFGNLATQVHSF', 'SHKFGNLATQVHSF', 'RFKFGNLGTQVHSC']
#
# Evaluation for Level 4-5:
#   Average Reward: 164.63 ± 4.75
#   Average SP Score: 3.87 ± 0.64
#   Perfect Match Rate: 0.85
#   Column Accuracy: 0.95
#   Avg Alignment Length: 14.2
#
# === Starting Level 4-6 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 141.15, Avg Loss: 9.3639, Epsilon: 0.399
# Episode 50, Avg Reward: 128.91, Avg Loss: 8.0108, Epsilon: 0.362
# Episode 100, Avg Reward: 128.07, Avg Loss: 7.9267, Epsilon: 0.329
# Early stopping at episode 126 due to no improvement
#
# Example produced alignments:
#   ['NWMGDHS-HRHRNQQ', 'NWIGDHS-RHRNVQ-', 'NWIGDHSRRKRNMQ-']
#   ['NWMGDHSHRHRNQQ', 'NWIGDHSRHRNVQ-', 'NWIGDHSRRKRNMQ']
#   ['NWMGDHSHRHRN--QQ', 'NWIGDHSRHRNV--Q-', 'NWIGDHSRRKRNMQ--']
#
# Evaluation for Level 4-6:
#   Average Reward: 167.05 ± 3.13
#   Average SP Score: 3.48 ± 0.34
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.63
#   Avg Alignment Length: 14.2
#
# === Starting Level 4-7 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 120.05, Avg Loss: 7.5844, Epsilon: 0.399
# Episode 50, Avg Reward: 128.51, Avg Loss: 7.7735, Epsilon: 0.362
# Episode 100, Avg Reward: 134.98, Avg Loss: 7.9503, Epsilon: 0.329
# Episode 150, Avg Reward: 127.93, Avg Loss: 7.8659, Epsilon: 0.299
# Early stopping at episode 180 due to no improvement
#
# Example produced alignments:
#   ['KLGMGYAEYYPEFP', 'KLGMAYAEHYKEIP', 'RLGQAYAEYYPEIP']
#   ['KLGMGYAEYYPEFP', 'KLGMAYAEHYKEIP', 'RLGQAYAEYYPEIP']
#   ['KLGMGYAEYYPEFP', 'KLGMAYAEHYKEIP', 'RLGQAYAEYYPEIP']
#
# Evaluation for Level 4-7:
#   Average Reward: 163.00 ± 0.89
#   Average SP Score: 3.96 ± 0.70
#   Perfect Match Rate: 0.95
#   Column Accuracy: 0.97
#   Avg Alignment Length: 14.1
#
# === Starting Level 4-8 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 154.15, Avg Loss: 7.8072, Epsilon: 0.399
# Episode 50, Avg Reward: 116.08, Avg Loss: 7.7134, Epsilon: 0.362
# Episode 100, Avg Reward: 117.23, Avg Loss: 7.6740, Epsilon: 0.329
# Early stopping at episode 125 due to no improvement
#
# Example produced alignments:
#   ['TVPGVHMFWNRQL', 'TVPSVHWRSAL--', 'TVPSVHWWNRSQL']
#   ['TVPGVHMFWNRQL', 'TVPSVHWRSAL--', 'TVPSVHWWNRSQL']
#   ['TVPGVHMFWNRQL', 'TVPSVHWRSAL--', 'TVPSVHWWNRSQL']
#
# Evaluation for Level 4-8:
#   Average Reward: 148.19 ± 1.70
#   Average SP Score: 2.07 ± 0.17
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.53
#   Avg Alignment Length: 13.1
#
# === Starting Level 4-9 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 110.92, Avg Loss: 7.1984, Epsilon: 0.399
# Episode 50, Avg Reward: 127.07, Avg Loss: 8.1195, Epsilon: 0.362
# Episode 100, Avg Reward: 134.33, Avg Loss: 7.5819, Epsilon: 0.329
# Early stopping at episode 148 due to no improvement
#
# Example produced alignments:
#   ['CGYMSNIEEIFSHE', 'CASMCNIEEIFSHE', 'CASMCSIEEIFSHE']
#   ['CGYMSNIEEIFSHE', 'CASMCNIEEIFSHE', 'CASMCSIEEIFSHE']
#   ['CGYMSNIEEIFSHE', 'CASMCNIEEIFSHE', 'CASMCSIEEIFSHE']
#
# Evaluation for Level 4-9:
#   Average Reward: 162.43 ± 4.59
#   Average SP Score: 4.20 ± 0.77
#   Perfect Match Rate: 0.95
#   Column Accuracy: 0.96
#   Avg Alignment Length: 14.1
#
# === Starting Level 5-0 (BLOSUM scoring) ===
# Reinitializing agent due to state size change (220 -> 285)
# Episode 0, Avg Reward: -324.88, Avg Loss: 0.0000, Epsilon: 0.250
# Episode 50, Avg Reward: -961.94, Avg Loss: 25.7345, Epsilon: 0.231
# Episode 100, Avg Reward: -177.95, Avg Loss: 24.6543, Epsilon: 0.214
# Episode 150, Avg Reward: 125.59, Avg Loss: 17.9750, Epsilon: 0.198
# Episode 200, Avg Reward: 125.29, Avg Loss: 15.9880, Epsilon: 0.184
# Early stopping at episode 226 due to no improvement
#
# Example produced alignments:
#   ['YPWQMRHDVYLTIDFY-', 'YPWQMRHDVYLTIDFY-', 'HPWQMRHDVYLTIDFY-', '-YPWNMRKDVYLTIDIS']
#   ['YPWQMRHDVYLTIDFY', 'YPWQMRHDVYLTIDFY', 'HPWQMRHDVYLTIDFY', 'YPWNMRKDVYLTIDIS']
#   ['YPWQMRHDVYLTIDFY', 'YPWQMRHDVYLTIDFY', 'HPWQMRHDVYLTIDFY', 'YPWNMRKDVYLTIDIS']
#
# Evaluation for Level 5-0:
#   Average Reward: 140.77 ± 6.72
#   Average SP Score: 3.35 ± 1.80
#   Perfect Match Rate: 0.50
#   Column Accuracy: 0.58
#   Avg Alignment Length: 16.6
#
# === Starting Level 5-1 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 134.53, Avg Loss: 10.7121, Epsilon: 0.250
# Episode 50, Avg Reward: 123.89, Avg Loss: 12.7123, Epsilon: 0.231
# Episode 100, Avg Reward: 124.03, Avg Loss: 12.9182, Epsilon: 0.214
# Episode 150, Avg Reward: 124.31, Avg Loss: 10.6149, Epsilon: 0.198
# Episode 200, Avg Reward: 120.46, Avg Loss: 10.6015, Epsilon: 0.184
# Episode 250, Avg Reward: 122.61, Avg Loss: 9.8753, Epsilon: 0.170
# Early stopping at episode 252 due to no improvement
#
# Example produced alignments:
#   ['A---FMLY-SLVSFMSMDHW', 'VFLLYVLVSFMSMDHW----', 'AF-MLYVLVSFMSLDHW---', 'A---FMLY-VLVSFMSMDHW']
#   ['AFMLYSLVSFMSMDHW-', 'V-FLLYVLVSFMSMDHW', 'AFMLYVLVSFMSLDHW-', 'AF-MLYVLVSFMSMDHW']
#   ['AFMLYSLVSFMSMDHW', 'VFLLYVLVSFMSMDHW', 'AFMLYVLVSFMSLDHW', 'AFMLYVLVSFMSMDHW']
#
# Evaluation for Level 5-1:
#   Average Reward: 133.88 ± 12.53
#   Average SP Score: 2.20 ± 2.18
#   Perfect Match Rate: 0.35
#   Column Accuracy: 0.42
#   Avg Alignment Length: 17.3
#
# === Starting Level 5-2 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 114.67, Avg Loss: 10.9746, Epsilon: 0.250
# Episode 50, Avg Reward: 109.21, Avg Loss: 9.8114, Epsilon: 0.231
# Episode 100, Avg Reward: 109.56, Avg Loss: 9.4127, Epsilon: 0.214
# Episode 150, Avg Reward: 114.27, Avg Loss: 9.5881, Epsilon: 0.198
# Early stopping at episode 194 due to no improvement
#
# Example produced alignments:
#   ['KLTMGLMGHIRMRWMM', 'KLVKGLAGHIRLKWMM', 'KIVMGLMGHIRMTWMM', 'KHIRMKWMM-------']
#   ['KLTMGLMGHIRMRWMM-', 'KLVKGLA-GHIRLKWMM', 'KIVMGLMGHIRMTWMM-', 'KHIRMKWMM--------']
#   ['KLTMGLMGHIRMRWMM-', 'KL-VKGLAGHIRLKWMM', 'KI-VMGLMGHIRMTWMM', 'KH-IRMKWMM-------']
#
# Evaluation for Level 5-2:
#   Average Reward: 127.35 ± 5.47
#   Average SP Score: 1.25 ± 0.69
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.06
#   Avg Alignment Length: 16.3
#
# === Starting Level 5-3 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 121.85, Avg Loss: 13.3186, Epsilon: 0.250
# Episode 50, Avg Reward: 126.02, Avg Loss: 8.6490, Epsilon: 0.231
# Episode 100, Avg Reward: 123.59, Avg Loss: 9.4315, Epsilon: 0.214
# Episode 150, Avg Reward: 127.70, Avg Loss: 8.3246, Epsilon: 0.198
# Episode 200, Avg Reward: 131.45, Avg Loss: 8.5921, Epsilon: 0.184
# Episode 250, Avg Reward: 127.92, Avg Loss: 8.9568, Epsilon: 0.170
# Early stopping at episode 287 due to no improvement
#
# Example produced alignments:
#   ['YPQKMSSGWGGAIVTK', 'YPQKMSSGWGGAPVKE', 'YPNKMSYGWGGAPVTK', 'YPQKMSSGWGGAPVTK']
#   ['YPQKMSSGWGGAIVTK-', 'YPQKMSSG-WGGAPVKE', 'YPNKMSYG-WGGAPVTK', 'YPQKMSSG-WGGAPVTK']
#   ['YPQKMSSGWGGAIVTK-', 'YPQKMSSGWGGAPV-KE', 'YPNKMSYGWGGAPVTK-', 'YPQKMSSGWGGAPV-TK']
#
# Evaluation for Level 5-3:
#   Average Reward: 141.86 ± 7.48
#   Average SP Score: 3.92 ± 1.46
#   Perfect Match Rate: 0.70
#   Column Accuracy: 0.81
#   Avg Alignment Length: 16.4
#
# === Starting Level 5-4 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 101.12, Avg Loss: 6.0596, Epsilon: 0.250
# Episode 50, Avg Reward: 124.38, Avg Loss: 8.4356, Epsilon: 0.231
# Episode 100, Avg Reward: 126.86, Avg Loss: 8.6103, Epsilon: 0.214
# Early stopping at episode 108 due to no improvement
#
# Example produced alignments:
#   ['QWPQHDIWPWTEPYGE', 'HWPQHDIWPWTEPKGE', 'HWPLHDIWPWTRPFGE', 'HWPQHDIWPHTEPFGE']
#   ['QWPQHDIWPWTEPYGE', 'HWPQHDIWPWTEPKGE', 'HWPLHDIWPWTRPFGE', 'HWPQHDIWPHTEPFGE']
#   ['QWPQHDIWPWTEPYGE', 'HWPQHDIWPWTEPKGE', 'HWPLHDIWPWTRPFGE', 'HWPQHDIWPHTEPFGE']
#
# Evaluation for Level 5-4:
#   Average Reward: 142.37 ± 6.67
#   Average SP Score: 5.01 ± 1.51
#   Perfect Match Rate: 0.85
#   Column Accuracy: 0.86
#   Avg Alignment Length: 16.1
#
# === Starting Level 5-5 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 99.96, Avg Loss: 14.1684, Epsilon: 0.250
# Episode 50, Avg Reward: 124.64, Avg Loss: 7.7995, Epsilon: 0.231
# Episode 100, Avg Reward: 125.02, Avg Loss: 8.0309, Epsilon: 0.214
# Early stopping at episode 105 due to no improvement
#
# Example produced alignments:
#   ['KVRRIMYTSMPLCING', 'KVQRNMFTRMPLCING', 'KVQRNMLTRMPLCING', 'KVRRTMVTRMVLCING']
#   ['KVRRIMYTSMPLCING', 'KVQRNMFTRMPLCING', 'KVQRNMLTRMPLCING', 'KVRRTMVTRMVLCING']
#   ['KVRRIMYTSMPLCING', 'KVQRNMFTRMPLCING', 'KVQRNMLTRMPLCING', 'KVRRTMVTRMVLCING']
#
# Evaluation for Level 5-5:
#   Average Reward: 143.32 ± 1.46
#   Average SP Score: 3.85 ± 0.61
#   Perfect Match Rate: 0.90
#   Column Accuracy: 0.95
#   Avg Alignment Length: 16.1
#
# === Starting Level 5-6 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 112.06, Avg Loss: 9.2925, Epsilon: 0.250
# Episode 50, Avg Reward: 127.01, Avg Loss: 8.0080, Epsilon: 0.231
# Episode 100, Avg Reward: 127.56, Avg Loss: 8.6110, Epsilon: 0.214
# Early stopping at episode 144 due to no improvement
#
# Example produced alignments:
#   ['GTATDGLFEYTMLTTY-', '-GEAQDGMFEAAMLTTY', 'GEAQDGMFEATMLTAY-', 'GEATDGMFEANMLTTY-']
#   ['GTATDGLFEYTMLTTY', 'GEAQDGMFEAAMLTTY', 'GEAQDGMFEATMLTAY', 'GEATDGMFEANMLTTY']
#   ['GTATDGLFEYTMLTTY', 'GEAQDGMFEAAMLTTY', 'GEAQDGMFEATMLTAY', 'GEATDGMFEANMLTTY']
#
# Evaluation for Level 5-6:
#   Average Reward: 142.01 ± 6.22
#   Average SP Score: 3.51 ± 0.96
#   Perfect Match Rate: 0.75
#   Column Accuracy: 0.85
#   Avg Alignment Length: 16.2
#
# === Starting Level 5-7 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 130.07, Avg Loss: 5.0439, Epsilon: 0.250
# Episode 50, Avg Reward: 119.83, Avg Loss: 8.7296, Epsilon: 0.231
# Episode 100, Avg Reward: 119.61, Avg Loss: 7.6702, Epsilon: 0.214
# Episode 150, Avg Reward: 122.39, Avg Loss: 7.4635, Epsilon: 0.198
# Episode 200, Avg Reward: 124.41, Avg Loss: 7.8473, Epsilon: 0.184
# Episode 250, Avg Reward: 128.69, Avg Loss: 7.8315, Epsilon: 0.170
# Early stopping at episode 272 due to no improvement
#
# Example produced alignments:
#   ['W-L-TPRLWLLWS-LNWHY', 'W-ATFWLLWALNW-AY---', 'W-AT-PNFWLLWSLNWAY-', 'RAT--PNFWLLWSLNWAY-']
#   ['WLTPRLWLLWSLNWHY', 'WATFWLLWALNWAY--', 'WATPNFWLLWSLNWAY', 'RATPNFWLLWSLNWAY']
#   ['WLTPRLWLLWSLNWHY', 'WATFWLLWALNWAY--', 'WATPNFWLLWSLNWAY', 'RATPNFWLLWSLNWAY']
#
# Evaluation for Level 5-7:
#   Average Reward: 135.02 ± 8.44
#   Average SP Score: 2.12 ± 0.73
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.18
#   Avg Alignment Length: 16.2
#
# === Starting Level 5-8 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 138.90, Avg Loss: 5.8447, Epsilon: 0.250
# Episode 50, Avg Reward: 120.80, Avg Loss: 7.7670, Epsilon: 0.231
# Episode 100, Avg Reward: 121.11, Avg Loss: 7.3200, Epsilon: 0.214
# Episode 150, Avg Reward: 122.67, Avg Loss: 7.1878, Epsilon: 0.198
# Episode 200, Avg Reward: 122.09, Avg Loss: 7.1572, Epsilon: 0.184
# Early stopping at episode 228 due to no improvement
#
# Example produced alignments:
#   ['LKWSVMFIMVRFEMYM-', 'LKWWQMFIMVSFEIYM-', 'LKWTDRMFIMVSFEIYM', 'LKWSRM-FIRVSFEIYM']
#   ['LKWSVMFIMVRFEMYM-', 'LKWWQMFIMVSFEIYM-', 'LKWTDRMFIMVSFEIYM', 'LKWSRMFIRVSFEIYM-']
#   ['LKWSVMFIMVRFEMYM-', 'LKWWQMFIMVSFEIYM-', 'LKWTDRMFIMVSFEIYM', 'LKWSRMFIRVSFEIYM-']
#
# Evaluation for Level 5-8:
#   Average Reward: 124.81 ± 2.54
#   Average SP Score: 2.07 ± 0.35
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.21
#   Avg Alignment Length: 17.0
#
# === Starting Level 5-9 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 116.03, Avg Loss: 9.5412, Epsilon: 0.250
# Episode 50, Avg Reward: 118.91, Avg Loss: 7.4747, Epsilon: 0.231
# Episode 100, Avg Reward: 119.70, Avg Loss: 7.5847, Epsilon: 0.214
# Episode 150, Avg Reward: 122.28, Avg Loss: 7.1587, Epsilon: 0.198
# Episode 200, Avg Reward: 121.83, Avg Loss: 7.1003, Epsilon: 0.184
# Episode 250, Avg Reward: 122.90, Avg Loss: 7.2725, Epsilon: 0.170
# Episode 300, Avg Reward: 124.56, Avg Loss: 7.1306, Epsilon: 0.158
# Early stopping at episode 308 due to no improvement
#
# Example produced alignments:
#   ['LMPQKWRPSHYVKFNC-', 'LMTQAKWRPSHYVRFHC', 'MLMQKWRPNHYVKFHC-', 'LMAHKWRPSHYVKFHC-']
#   ['LMPQKWRPSHYVKFNC--', 'LMTQ-AKWRPSHYVRFHC', 'MLMQ-KWRPNHYVKFHC-', 'LMAH-KWRPSHYVKFHC-']
#   ['LMPQKWRPSHYVKFNC-', 'LMTQAKWRPSHYVRFHC', 'MLMQKWRPNHYVKFHC-', 'LMAHKWRPSHYVKFHC-']
#
# Evaluation for Level 5-9:
#   Average Reward: 129.44 ± 5.00
#   Average SP Score: 2.02 ± 0.96
#   Perfect Match Rate: 0.05
#   Column Accuracy: 0.30
#   Avg Alignment Length: 17.1
#
# === Starting Level 6-0 (BLOSUM scoring) ===
# Reinitializing agent due to state size change (285 -> 155)
# Episode 0, Avg Reward: -902.40, Avg Loss: 0.0000, Epsilon: 0.200
# Episode 50, Avg Reward: -555.45, Avg Loss: 27.6025, Epsilon: 0.189
# Episode 100, Avg Reward: 283.04, Avg Loss: 16.5104, Epsilon: 0.178
# Episode 150, Avg Reward: 300.33, Avg Loss: 14.3437, Epsilon: 0.168
# Early stopping at episode 173 due to no improvement
#
# Example produced alignments:
#   ['TWWSITEYSVSCKARGWD', 'PSWPMPEYAVSCKARGWN']
#   ['TWWSITEYSVSCKARGWD', 'PSWPMPEYAVSCKARGWN']
#   ['TWWSITEYSVSCKARGWD-', 'PSWPMPEYAVSCKARG-WN']
#
# Evaluation for Level 6-0:
#   Average Reward: 402.56 ± 45.90
#   Average SP Score: 3.22 ± 1.46
#   Perfect Match Rate: 0.85
#   Column Accuracy: 0.93
#   Avg Alignment Length: 18.1
#
# === Starting Level 6-1 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 408.75, Avg Loss: 9.3289, Epsilon: 0.200
# Episode 50, Avg Reward: 308.68, Avg Loss: 14.6079, Epsilon: 0.189
# Episode 100, Avg Reward: 274.95, Avg Loss: 13.7128, Epsilon: 0.178
# Episode 150, Avg Reward: 304.13, Avg Loss: 14.2137, Epsilon: 0.168
# Early stopping at episode 186 due to no improvement
#
# Example produced alignments:
#   ['SAVNIQQDGIRIALGEHR', 'SARNIQQDRTKIHLGEHR']
#   ['SAVNIQQDGIRIALGEHR', 'SARNIQQDRTKIHLGEHR']
#   ['SAVNIQQDGIRIALGEHR', 'SARNIQQDRTKIHLGEHR']
#
# Evaluation for Level 6-1:
#   Average Reward: 400.82 ± 38.07
#   Average SP Score: 2.94 ± 1.23
#   Perfect Match Rate: 0.90
#   Column Accuracy: 0.94
#   Avg Alignment Length: 18.1
#
# === Starting Level 6-2 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 373.85, Avg Loss: 16.3217, Epsilon: 0.200
# Episode 50, Avg Reward: 285.26, Avg Loss: 13.1846, Epsilon: 0.189
# Episode 100, Avg Reward: 309.65, Avg Loss: 12.6729, Epsilon: 0.178
# Early stopping at episode 148 due to no improvement
#
# Example produced alignments:
#   ['MTTQPKWCPKEVFKDQVD', 'ITTQPKWCPKEVFNDQAD']
#   ['MTTQPKWCPKEVFKDQVD', 'ITTQPKWCPKEVFNDQAD']
#   ['MTTQPKWCP-KEVFKDQVD', 'ITTQPKWCPKEVFNDQAD-']
#
# Evaluation for Level 6-2:
#   Average Reward: 401.64 ± 34.52
#   Average SP Score: 4.60 ± 1.62
#   Perfect Match Rate: 0.90
#   Column Accuracy: 0.93
#   Avg Alignment Length: 18.1
#
# === Starting Level 6-3 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 210.60, Avg Loss: 10.8156, Epsilon: 0.200
# Episode 50, Avg Reward: 266.54, Avg Loss: 14.3998, Epsilon: 0.189
# Episode 100, Avg Reward: 304.30, Avg Loss: 15.1946, Epsilon: 0.178
# Episode 150, Avg Reward: 285.41, Avg Loss: 14.9338, Epsilon: 0.168
# Episode 200, Avg Reward: 318.38, Avg Loss: 14.7776, Epsilon: 0.159
# Episode 250, Avg Reward: 315.27, Avg Loss: 14.9846, Epsilon: 0.150
# Episode 300, Avg Reward: 319.74, Avg Loss: 15.2094, Epsilon: 0.141
# Early stopping at episode 343 due to no improvement
#
# Example produced alignments:
#   ['WGNMQPCERDHGHGFTIY-', 'EGNMGPCKRD-HAHGFAIY']
#   ['WGNMQPCERDHGHGFTIY', 'EGNMGPCKRDHAHGFAIY']
#   ['WGNMQPCERDHGHGFTIY', 'EGNMGPCKRDHAHGFAIY']
#
# Evaluation for Level 6-3:
#   Average Reward: 409.46 ± 21.97
#   Average SP Score: 3.90 ± 1.30
#   Perfect Match Rate: 0.85
#   Column Accuracy: 0.94
#   Avg Alignment Length: 18.1
#
# === Starting Level 6-4 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 285.30, Avg Loss: 13.7443, Epsilon: 0.200
# Episode 50, Avg Reward: 306.19, Avg Loss: 15.1028, Epsilon: 0.189
# Episode 100, Avg Reward: 306.26, Avg Loss: 14.4728, Epsilon: 0.178
# Episode 150, Avg Reward: 293.54, Avg Loss: 15.4821, Epsilon: 0.168
# Early stopping at episode 167 due to no improvement
#
# Example produced alignments:
#   ['ETVFTAWEWFTMLMWTQM', 'QTVFTAWEWFTMLMWTQM']
#   ['ETVFTAWEWFTMLMWTQM', 'QTVFTAWEWFTMLMWTQM']
#   ['ETVFTAWEWFTMLMWTQM', 'QTVFTAWEWFTMLMWTQM']
#
# Evaluation for Level 6-4:
#   Average Reward: 400.47 ± 42.36
#   Average SP Score: 5.24 ± 1.69
#   Perfect Match Rate: 0.90
#   Column Accuracy: 0.93
#   Avg Alignment Length: 18.1
#
# === Starting Level 6-5 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 496.20, Avg Loss: 14.4655, Epsilon: 0.200
# Episode 50, Avg Reward: 269.61, Avg Loss: 15.1526, Epsilon: 0.189
# Episode 100, Avg Reward: 295.16, Avg Loss: 14.8751, Epsilon: 0.178
# Episode 150, Avg Reward: 300.68, Avg Loss: 14.9394, Epsilon: 0.168
# Early stopping at episode 172 due to no improvement
#
# Example produced alignments:
#   ['EGNSERDKTIYGWTQQTF', 'EGNEERDKTIYGWHHETF']
#   ['EGNSERDKTIYGWTQQTF-', 'EGNEERDKTIYGWHHET-F']
#   ['EGNSERDKTIYGWTQQTF', 'EGNEERDKTIYGWHHETF']
#
# Evaluation for Level 6-5:
#   Average Reward: 411.69 ± 27.51
#   Average SP Score: 4.17 ± 1.10
#   Perfect Match Rate: 0.85
#   Column Accuracy: 0.96
#   Avg Alignment Length: 18.1
#
# === Starting Level 6-6 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 199.15, Avg Loss: 14.8005, Epsilon: 0.200
# Episode 50, Avg Reward: 302.01, Avg Loss: 15.0575, Epsilon: 0.189
# Episode 100, Avg Reward: 315.08, Avg Loss: 15.3803, Epsilon: 0.178
# Episode 150, Avg Reward: 309.03, Avg Loss: 15.1412, Epsilon: 0.168
# Early stopping at episode 158 due to no improvement
#
# Example produced alignments:
#   ['AYIDYYLCQMGVMWSMYS', 'AYIEYYLCQMGVMWSMYS']
#   ['AYIDYYLCQMGVMWSMYS', 'AYIEYYLCQMGVMWSMYS']
#   ['AYIDYYLCQMGVMWSMYS', 'AYIEYYLCQMGVMWSMYS']
#
# Evaluation for Level 6-6:
#   Average Reward: 404.82 ± 26.07
#   Average SP Score: 5.25 ± 1.31
#   Perfect Match Rate: 0.95
#   Column Accuracy: 0.96
#   Avg Alignment Length: 18.1
#
# === Starting Level 6-7 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 236.65, Avg Loss: 14.2143, Epsilon: 0.200
# Episode 50, Avg Reward: 312.54, Avg Loss: 15.5998, Epsilon: 0.189
# Episode 100, Avg Reward: 323.64, Avg Loss: 14.7953, Epsilon: 0.178
# Episode 150, Avg Reward: 301.95, Avg Loss: 15.1650, Epsilon: 0.168
# Episode 200, Avg Reward: 335.01, Avg Loss: 14.7676, Epsilon: 0.159
# Episode 250, Avg Reward: 358.69, Avg Loss: 15.3883, Epsilon: 0.150
# Early stopping at episode 259 due to no improvement
#
# Example produced alignments:
#   ['SGIATPSEKLLKRMSHHQ', 'SGIATPSKKQLKRMSHCQ']
#   ['SGIATPSEKLLKRMSHHQ', 'SGIATPSKKQLKRMSHCQ']
#   ['SGIATPSEK-LLKRMSHHQ', 'SGIATPSKKQLKRMSHCQ-']
#
# Evaluation for Level 6-7:
#   Average Reward: 406.30 ± 24.60
#   Average SP Score: 3.47 ± 1.02
#   Perfect Match Rate: 0.80
#   Column Accuracy: 0.91
#   Avg Alignment Length: 18.2
#
# === Starting Level 6-8 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 269.40, Avg Loss: 14.8855, Epsilon: 0.200
# Episode 50, Avg Reward: 286.04, Avg Loss: 15.4965, Epsilon: 0.189
# Episode 100, Avg Reward: 287.31, Avg Loss: 15.4625, Epsilon: 0.178
# Episode 150, Avg Reward: 307.26, Avg Loss: 15.2941, Epsilon: 0.168
# Episode 200, Avg Reward: 307.61, Avg Loss: 14.9677, Epsilon: 0.159
# Episode 250, Avg Reward: 311.74, Avg Loss: 15.0837, Epsilon: 0.150
# Early stopping at episode 285 due to no improvement
#
# Example produced alignments:
#   ['YSMMNADYEFCQGERKYF', 'YTMMDAEHEFCHGQRKYF']
#   ['YSMMNADYEFCQGERKYF', 'YTMMDAEHEFCHGQRKYF']
#   ['YSMMNADYEFCQGERKYF', 'YTMMDAEHEFCHGQRKYF']
#
# Evaluation for Level 6-8:
#   Average Reward: 396.86 ± 38.42
#   Average SP Score: 3.84 ± 1.49
#   Perfect Match Rate: 0.90
#   Column Accuracy: 0.92
#   Avg Alignment Length: 18.1
#
# === Starting Level 6-9 (BLOSUM scoring) ===
# Episode 0, Avg Reward: 337.15, Avg Loss: 15.4289, Epsilon: 0.200
# Episode 50, Avg Reward: 323.68, Avg Loss: 15.6459, Epsilon: 0.189
# Episode 100, Avg Reward: 332.26, Avg Loss: 15.1628, Epsilon: 0.178
# Episode 150, Avg Reward: 297.77, Avg Loss: 15.1618, Epsilon: 0.168
# Early stopping at episode 180 due to no improvement
#
# Example produced alignments:
#   ['WPDSCANAMDVMYHIDEQ--', 'WPDSCANAMDAM-YHI-DEQ']
#   ['WPDSCANAMDVMYHIDEQ', 'WPDSCANAMDAMYHIDEQ']
#   ['WPDSCANAMDVMYHIDEQ', 'WPDSCANAMDAMYHIDEQ']
#
# Evaluation for Level 6-9:
#   Average Reward: 416.59 ± 17.31
#   Average SP Score: 5.42 ± 0.82
#   Perfect Match Rate: 0.90
#   Column Accuracy: 0.98
#   Avg Alignment Length: 18.1
#
# === Starting Level 7-0 (BLOSUM scoring) ===
# Reinitializing agent due to state size change (155 -> 220)
# Episode 0, Avg Reward: -2903.10, Avg Loss: 0.0000, Epsilon: 0.200
# Episode 50, Avg Reward: -1012.54, Avg Loss: 37.8334, Epsilon: 0.190
# Episode 100, Avg Reward: -2.70, Avg Loss: 21.7187, Epsilon: 0.180
# Episode 150, Avg Reward: -16.73, Avg Loss: 14.2146, Epsilon: 0.171
# Episode 200, Avg Reward: -307.44, Avg Loss: 13.1543, Epsilon: 0.163
# Early stopping at episode 205 due to no improvement
#
# Example produced alignments:
#   ['TMFEVMLKDRQLDAAADMIQ--------------------', 'TMFEVCLKDRQLDASVDMIQ--------------------', '---------------------F------------------']
#   ['TMFEVMLKDRQLDAAADMIQ--------------------', 'TMFEVCLKDRQLDASVDMIQ--------------------', '----------------------------------------']
#   ['TMFEVMLKDRQLDAAADMIQ--------------------', 'TMFEVCLKDRQLDASVDMIQ--------------------', '----------------------------------------']
#
# ...
#   ['--MT--T-Q---P-KWC-PK-E------VFK---D-', 'IT--TQ-PKWCPKE-V-F-ND-QAD-----------']
#
# Evaluation for Level 6-2:
#   Average Reward: -5655.00 ± 608.92
#   Average SP Score: -2.50 ± 1.82
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.01
#   Avg Alignment Length: 35.8
#
# === Starting Level 6-3 (INTELLIALIGN scoring) ===
# Episode 0, Avg Reward: -5318.15, Avg Loss: 163.5843, Epsilon: 0.200
# Episode 50, Avg Reward: -5730.85, Avg Loss: 157.5469, Epsilon: 0.189
# Episode 100, Avg Reward: -5720.87, Avg Loss: 158.9445, Epsilon: 0.178
# Episode 150, Avg Reward: -5896.48, Avg Loss: 159.4375, Epsilon: 0.168
# Early stopping at episode 181 due to no improvement
#
# Example produced alignments:
#   ['W--GNM------QPC--ER-----D--H-GHGF--T', '-EGNM-GPCKRDH--AHG-FAIY-------------']
#   ['-W------G---NMQ-P--C-------E--------', 'E-GNMGPC-KRD--HA-HG-FAIY------------']
#   ['--W-------G-N-MQPCE----R---D---H----', 'EG-NMGPCKR-DHA-H--GFAIY-------------']
#
# Evaluation for Level 6-3:
#   Average Reward: -6055.34 ± 567.22
#   Average SP Score: -2.67 ± 1.74
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.00
#   Avg Alignment Length: 35.9
#
# === Starting Level 6-4 (INTELLIALIGN scoring) ===
# Episode 0, Avg Reward: -6142.54, Avg Loss: 158.0475, Epsilon: 0.200
# Episode 50, Avg Reward: -5885.84, Avg Loss: 160.8525, Epsilon: 0.189
# Episode 100, Avg Reward: -5719.52, Avg Loss: 161.6844, Epsilon: 0.178
# Early stopping at episode 113 due to no improvement
#
# Example produced alignments:
#   ['-------E-TVFT---A---WE-W-F---TM--L-M', 'QTVFTAW-E--W-FTM-LMWTQM-------------']
#   ['----E---------T--V--FTA-W-EW-FTM-LM-', 'QTVF-TAWEWFTML-MWTQM----------------']
#   ['--E---T---V---------FT---A--WE----W-', 'QT-VFT-AWE-WFTMLMWTQ--M-------------']
#
# Evaluation for Level 6-4:
#   Average Reward: -5522.29 ± 634.61
#   Average SP Score: -2.15 ± 1.86
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.01
#   Avg Alignment Length: 35.9
#
# === Starting Level 6-5 (INTELLIALIGN scoring) ===
# Episode 0, Avg Reward: -6436.10, Avg Loss: 160.4663, Epsilon: 0.200
# Episode 50, Avg Reward: -5845.59, Avg Loss: 161.4399, Epsilon: 0.189
# Episode 100, Avg Reward: -6022.74, Avg Loss: 161.8636, Epsilon: 0.178
# Early stopping at episode 103 due to no improvement
#
# Example produced alignments:
#   ['--E-GN----S----E-RD-----K-TIY-G-W-T-', 'EG-NEERDKT-IYGW-HH-ETF--------------']
#   ['--EGNSE----R----D-K---T---I-Y--GWT--', 'EG-N--EERDKTIYGWHH-ETF--------------']
#   ['--E-GN-SE------R--D--KTI------YG--W-', 'EGNE--E-RDKTIYG-WHHET---F-----------']
#
# Evaluation for Level 6-5:
#   Average Reward: -5735.33 ± 667.55
#   Average SP Score: -1.69 ± 1.55
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.01
#   Avg Alignment Length: 35.8
#
# === Starting Level 6-6 (INTELLIALIGN scoring) ===
# Episode 0, Avg Reward: -5982.73, Avg Loss: 160.9319, Epsilon: 0.200
# Episode 50, Avg Reward: -5806.58, Avg Loss: 162.2826, Epsilon: 0.189
# Episode 100, Avg Reward: -5829.34, Avg Loss: 163.4902, Epsilon: 0.178
# Episode 150, Avg Reward: -5831.15, Avg Loss: 162.4877, Epsilon: 0.168
# Early stopping at episode 191 due to no improvement
#
# Example produced alignments:
#   ['A-YID----Y-Y-L-C--Q--M-GV--M-W-SMY--', '-AY--IEYY-L-C-QMGVMWSMYS------------']
#   ['-A--Y-I--D---YY---L-C--------QMG--V-', 'AYIEYYLCQ-MGV-MWSMYS----------------']
#   ['---AYI--D-YYLC-Q-M-GVMWS-M--Y---S', 'AYI---EYYL---CQMG-V--MW-SMYS-----']
#
# Evaluation for Level 6-6:
#   Average Reward: -6012.28 ± 603.42
#   Average SP Score: -2.43 ± 1.75
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.01
#   Avg Alignment Length: 35.7
#
# === Starting Level 6-7 (INTELLIALIGN scoring) ===
# Episode 0, Avg Reward: -4909.15, Avg Loss: 162.3995, Epsilon: 0.200
# Episode 50, Avg Reward: -6037.56, Avg Loss: 163.2365, Epsilon: 0.189
# Episode 100, Avg Reward: -5867.37, Avg Loss: 164.6608, Epsilon: 0.178
# Early stopping at episode 134 due to no improvement
#
# Example produced alignments:
#   ['SGI-AT--P-SE-KL---L--K-R-MS--HH---Q', '-S-G--IATP-SKKQLKRMSHCQ------------']
#   ['S--G------IA-T-P--S--E-K---LLKR----M', '-SGIATPSKKQ-L-K-RM-SH-CQ------------']
#   ['-----SGI-ATP-S--E---KLL-KRMSHH--Q', 'SGIATPS-K--KQ-LK-RMSH-CQ---------']
#
# Evaluation for Level 6-7:
#   Average Reward: -6147.94 ± 613.41
#   Average SP Score: -2.69 ± 1.72
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.00
#   Avg Alignment Length: 35.8
#
# === Starting Level 6-8 (INTELLIALIGN scoring) ===
# Episode 0, Avg Reward: -6180.45, Avg Loss: 162.5453, Epsilon: 0.200
# Episode 50, Avg Reward: -5888.69, Avg Loss: 163.2433, Epsilon: 0.189
# Episode 100, Avg Reward: -5718.33, Avg Loss: 163.4184, Epsilon: 0.178
# Episode 150, Avg Reward: -5978.19, Avg Loss: 164.7074, Epsilon: 0.168
# Episode 200, Avg Reward: -5937.03, Avg Loss: 164.8404, Epsilon: 0.159
# Early stopping at episode 229 due to no improvement
#
# Example produced alignments:
#   ['-Y----S--MMN-ADYEF--CQG--E--R-K-Y---', 'YTMMDA-EH---E-----FCHGQRKYF---------']
#   ['-Y--------S--MMNA-D-Y-E-F-CQG-----ER', 'Y-TMMDAEHEFCHG-Q-RKYF---------------']
#   ['Y-------S-----M-M---NA-DY--EFC-QG---', '-YTMMDAE-HEFCHGQ-RKYF---------------']
#
# Evaluation for Level 6-8:
#   Average Reward: -5943.86 ± 766.44
#   Average SP Score: -2.38 ± 1.77
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.01
#   Avg Alignment Length: 35.8
#
# === Starting Level 6-9 (INTELLIALIGN scoring) ===
# Episode 0, Avg Reward: -5961.99, Avg Loss: 160.6445, Epsilon: 0.200
# Episode 50, Avg Reward: -5777.79, Avg Loss: 163.9405, Epsilon: 0.189
# Episode 100, Avg Reward: -5730.85, Avg Loss: 164.4463, Epsilon: 0.178
# Early stopping at episode 129 due to no improvement
#
# Example produced alignments:
#   ['---W----P--DS---C-ANA-MD-------VM---', 'WPDSCANA-MD-AMYHID---E-Q------------']
#   ['-W---P--D-----SC--A-N--AM--DV------M', 'WPDSCANA-MDAMY--HI-D-EQ-------------']
#   ['--------W--PD--SC-AN--A-M--D--VMY-HI', 'WPDSCANA-MD--AMY-H-IDE-Q------------']
#
# Evaluation for Level 6-9:
#   Average Reward: -5608.94 ± 761.45
#   Average SP Score: -2.54 ± 1.96
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.01
#   Avg Alignment Length: 36.0
#
# === Starting Level 7-0 (INTELLIALIGN scoring) ===
# Reinitializing agent due to state size change (155 -> 220)
# Episode 0, Avg Reward: -8285.47, Avg Loss: 0.0000, Epsilon: 0.200
# Episode 50, Avg Reward: -7166.84, Avg Loss: 183.7728, Epsilon: 0.190
# Episode 100, Avg Reward: -7761.75, Avg Loss: 184.9261, Epsilon: 0.180
# Early stopping at episode 140 due to no improvement
#
# Example produced alignments:
#   ['TM--F-EV---M-L--K-DR---Q----LD--AAAD-MIQ', '---T-M---FE-V-C--L--K------D--R---------', 'FEV-C-LKRRQ----I--D-AANMIQ--------------']
#   ['T--M----FEVM-L-K---D----R----Q-LDA--A--A', '--T-MFEV------C--LK------DR-Q-L------D--', 'FE---V---CL-KRR-Q---IDAA-NMI-Q----------']
#   ['T--M---FE-V-M---L-K-D----R--QLD-A-A-A---', '-T----M--F-----------E----VC---L-----KD-', 'F-E-VC---LKRRQID-A-A-NMIQ---------------']
#
# Evaluation for Level 7-0:
#   Average Reward: -8058.87 ± 435.67
#   Average SP Score: -1.77 ± 1.16
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.00
#   Avg Alignment Length: 40.0
#
# === Starting Level 7-1 (INTELLIALIGN scoring) ===
# Episode 0, Avg Reward: -6691.58, Avg Loss: 173.6225, Epsilon: 0.200
# Episode 50, Avg Reward: -7386.46, Avg Loss: 182.9322, Epsilon: 0.190
# Episode 100, Avg Reward: -7597.29, Avg Loss: 185.2158, Epsilon: 0.180
# Early stopping at episode 102 due to no improvement
#
# Example produced alignments:
#   ['----S-M---Q--A--QL------DAQ-KG----S---IQ', 'SMQA-Q-L---DA--Q--QGSPIC-W-S---E--------', 'S-------MD--A-QL------DR---Q--KG---SI---']
#   ['SM-QAQL-D--A--QK--G----S---I------Q-S-I-', '--S----M-Q---A--QL--DA--Q-QG-SP--ICW---S', '----S-----M-D------A--QL-DR-Q--KG----S--']
#   ['----SM-Q------A---QL-DAQK-G-SI--QS-I--C-', 'SMQ--AQ--L-DAQ-QGS--PI-C-W-S--E---------', 'S--M----D-A-QL---DR----------QK---GS-I-Q']
#
# Evaluation for Level 7-1:
#   Average Reward: -7638.68 ± 513.78
#   Average SP Score: -2.34 ± 1.03
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.00
#   Avg Alignment Length: 40.0
#
# === Starting Level 7-2 (INTELLIALIGN scoring) ===
# Episode 0, Avg Reward: -7293.73, Avg Loss: 187.6825, Epsilon: 0.200
# Episode 50, Avg Reward: -7475.70, Avg Loss: 183.9944, Epsilon: 0.190
# Episode 100, Avg Reward: -7390.61, Avg Loss: 184.3443, Epsilon: 0.180
# Episode 150, Avg Reward: -7518.77, Avg Loss: 185.9977, Epsilon: 0.171
# Episode 200, Avg Reward: -7556.87, Avg Loss: 183.7083, Epsilon: 0.163
# Early stopping at episode 245 due to no improvement
#
# Example produced alignments:
#   ['-AFV-V--YE--G-Q-FEE---A---C--C--S--K--L-', 'A---W-VV--YEGLFEQ--ACC-SK--LPC---E------', 'T---F-V--V-Y-E-G--LFE----D-AC-SK--LACE--']
#   ['-A--F-V---V-YEG--Q--FE--E--A---C-C--S---', 'A--WV-VYEG-L----F-EQ--A--C--CSK-L--P-C-E', 'T-F--V--VY-E-G-LFED-AC-S-KL-A--CE-------']
#   ['-A-FVVYEGQF--E--EA---C-C-S-KLPCE--------', '--A--W-----V--VY-EGLF---E-Q----A-C------', 'T-F-V----V--YE-G--L---F-E----D----AC-S--']
#
# Evaluation for Level 7-2:
#   Average Reward: -7560.72 ± 568.97
#   Average SP Score: -2.33 ± 1.17
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.00
#   Avg Alignment Length: 40.0
#
# === Starting Level 7-3 (INTELLIALIGN scoring) ===
# Episode 0, Avg Reward: -7504.48, Avg Loss: 178.4392, Epsilon: 0.200
# Episode 50, Avg Reward: -7525.32, Avg Loss: 185.6975, Epsilon: 0.190
# Episode 100, Avg Reward: -7403.87, Avg Loss: 186.2960, Epsilon: 0.180
# Episode 150, Avg Reward: -7608.44, Avg Loss: 185.4674, Epsilon: 0.171
# Early stopping at episode 176 due to no improvement
#
# Example produced alignments:
#   ['-----QKA-------F---F-------QPD-QTEE----V', 'NK-AY----FQ--PK-QT--EEVLER----R-C--Y-S--', '-GK-AY-FQ-PEQ-T-DEV-LDR-RCY-S-----------']
#   ['---QK-A-FF----QPDQ---TEE-VL------D-N--RC', 'NKA-----YFQ---P-K-QTE---E-VL-ERRC-Y-S---', 'GKA-YF-Q--PEQT----DEV--L-D--R--R--C--Y--']
#   ['Q---KAFFQPD-----Q---T-E-EV--LD-NR-CW--S-', 'NKA--------YFQPK-QTE-E-V---L--E-R-R-C-YS', '--GK---A-Y--FQPE-------Q--T------D--EV-L']
#
# Evaluation for Level 7-3:
#   Average Reward: -7553.13 ± 741.91
#   Average SP Score: -3.27 ± 0.90
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.00
#   Avg Alignment Length: 40.0
#
# === Starting Level 7-4 (INTELLIALIGN scoring) ===
# Episode 0, Avg Reward: -8071.71, Avg Loss: 180.2833, Epsilon: 0.200
# Episode 50, Avg Reward: -7351.60, Avg Loss: 186.4581, Epsilon: 0.190
# Episode 100, Avg Reward: -7367.38, Avg Loss: 185.9208, Epsilon: 0.180
# Episode 150, Avg Reward: -7455.61, Avg Loss: 186.4524, Epsilon: 0.171
# Episode 200, Avg Reward: -7506.89, Avg Loss: 185.4245, Epsilon: 0.163
# Early stopping at episode 220 due to no improvement
#
# Example produced alignments:
#   ['D--PY--V-A---YY-FM-AA---EP-----RC-DCK-YM', '-EP--H--V-AYY-SM--A--A----KLC-D--C--K---', '--D---P-H-VA-Y------NSMA--A--QL--RCD-C--']
#   ['D-P-YV-----A-Y-YF-M-A-A-E--P-RC--D----C-', '-E-P--H-VA----YYS----M----A-A---K-L-C--D', '---D--PHVAYNS----M-A---A-Q----LR--CD-C--']
#   ['--DP-Y---V--AYYFMAA--E--P--RC-D---CK-Y-M', '---EP---H-VA--------Y--Y-S---M--A---A---', 'DP--H-VAY-NSM---A--AQ-LR-CD----CNY--M---']
#
# Evaluation for Level 7-4:
#   Average Reward: -7477.03 ± 694.19
#   Average SP Score: -2.63 ± 1.11
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.00
#   Avg Alignment Length: 40.0
#
# === Starting Level 7-5 (INTELLIALIGN scoring) ===
# Episode 0, Avg Reward: -8225.46, Avg Loss: 182.3034, Epsilon: 0.200
# Episode 50, Avg Reward: -7455.53, Avg Loss: 186.1303, Epsilon: 0.190
# Episode 100, Avg Reward: -7391.44, Avg Loss: 185.7937, Epsilon: 0.180
# Episode 150, Avg Reward: -7431.13, Avg Loss: 186.1472, Epsilon: 0.171
# Early stopping at episode 151 due to no improvement
#
# Example produced alignments:
#   ['---NNCQ------F-L--V-YD-AFA------WY--RQ--', '-EN----CQFLNY-D-AM-A------W---YH--Q-----', 'ENC----S---F--L-N-----Y--D-LMAWY---HE-FW']
#   ['--------------N-N--CQF-L-V-Y----DA-FAW-Y', '-E-NCQF--L-NYD---AM---A---W-YH----------', 'E-N-CS-FLNYDL--M-A----W-Y-HE-FWK--W-----']
#   ['--N-NCQFL---VYDA--FAWYRQFWK--W----------', '-E-N-----CQF---LN----------------Y---DA-', 'E----N-C-----S--FL-N-----Y-DL--M----A-WY']
#
# Evaluation for Level 7-5:
#   Average Reward: -7615.55 ± 508.27
#   Average SP Score: -2.71 ± 1.33
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.00
#   Avg Alignment Length: 40.0
#
# === Starting Level 7-6 (INTELLIALIGN scoring) ===
# Episode 0, Avg Reward: -7017.77, Avg Loss: 180.4341, Epsilon: 0.200
# Episode 50, Avg Reward: -7326.57, Avg Loss: 185.3449, Epsilon: 0.190
# Episode 100, Avg Reward: -7403.91, Avg Loss: 184.1720, Epsilon: 0.180
# Early stopping at episode 104 due to no improvement
#
# Example produced alignments:
#   ['P----AR--NAA------QA-LPNP----MV-Q-D-T-ED', '-P-AR-NA----AQA--L--P--N--P--M-V---Q-E--', 'PASNA--GLA----LHNPM--V---Q-ET----E-EE---']
#   ['-PA-----R-N--A-A---Q-A---LP--N-P---MV--Q', '----PA-R-N--AAQ-AL--P-N-----P-M--VQ--ET-', 'PA-S-NAG--LAL-HNPMV-Q-ETE--E----E-------']
#   ['PA-R-NAAQ-AL---P--NP-M---VQ-------DT-EDE', 'PAR-N--------AA--QA-----LP-NPM--VQ--E---', '--PASNA--G-LALH-NP--MVQE---T--EE-E------']
#
# Evaluation for Level 7-6:
#   Average Reward: -7515.84 ± 752.21
#   Average SP Score: -2.54 ± 1.01
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.00
#   Avg Alignment Length: 40.0
#
# === Starting Level 7-7 (INTELLIALIGN scoring) ===
# Episode 0, Avg Reward: -7862.24, Avg Loss: 185.1086, Epsilon: 0.200
# Episode 50, Avg Reward: -7316.69, Avg Loss: 185.7607, Epsilon: 0.190
# Episode 100, Avg Reward: -7188.05, Avg Loss: 185.7311, Epsilon: 0.180
# Episode 150, Avg Reward: -7490.26, Avg Loss: 185.1846, Epsilon: 0.171
# Early stopping at episode 168 due to no improvement
#
# Example produced alignments:
#   ['--NF-------W-----P---NE-T-C--FD--R-W-LH-', 'NF-WPNETCF--DRV--LHSA--EHD-L------------', '-NF-WP-NEAC-F-DRIL-H-KAG----------N-D--L']
#   ['-N-FW-PNET-CF-DR-W--LH--S---A-GNDL------', 'N-F--W----------P-NE-TCFDR-V------LHSAE-', '----------N--FW-P------N-EAC-F-DR-I---L-']
#   ['N--FW-------P-N-----E-----T--CF-DRWL-HSA', '-N-F-WP-NETC-F--DRVL-H--SA---E--H--D----', '--N--F-WP--NEACFD----RILH--KA--G----N--D']
#
# Evaluation for Level 7-7:
#   Average Reward: -7466.06 ± 639.74
#   Average SP Score: -2.60 ± 1.18
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.00
#   Avg Alignment Length: 40.0
#
# === Starting Level 7-8 (INTELLIALIGN scoring) ===
# Episode 0, Avg Reward: -7395.41, Avg Loss: 188.4202, Epsilon: 0.200
# Episode 50, Avg Reward: -7517.35, Avg Loss: 185.8754, Epsilon: 0.190
# Episode 100, Avg Reward: -7540.01, Avg Loss: 185.9856, Epsilon: 0.180
# Episode 150, Avg Reward: -7427.85, Avg Loss: 186.3067, Epsilon: 0.171
# Episode 200, Avg Reward: -7499.64, Avg Loss: 186.4977, Epsilon: 0.163
# Early stopping at episode 218 due to no improvement
#
# Example produced alignments:
#   ['FS--ISL-W---YGE--F-W--L---V-H-CV--EW-G-I', 'F-SI-----S-L---WY---G--EF----WL-QHC-V---', '--FS-S-S-LWY---GE-F--W--LV-H-C------VEW-']
#   ['--FS-I----S-L-----------WY-GEF--WL---VHC', '-F-----S---I-SL-WYGEFW-L------QH--CVE---', 'FS-SS-LWYGE---FWL-VH-CV---E--WGI--------']
#   ['FSIS-LWY-GEF-WL-V--HC-VEWG-I------------', 'FS----------I--S-LW---Y--GE--F-WL-Q-H---', '----F-S-S------S-----L----W-Y-GE-F-WLVH-']
#
# Evaluation for Level 7-8:
#   Average Reward: -7701.22 ± 601.16
#   Average SP Score: -2.76 ± 1.27
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.00
#   Avg Alignment Length: 40.0
#
# === Starting Level 7-9 (INTELLIALIGN scoring) ===
# Episode 0, Avg Reward: -6745.34, Avg Loss: 178.0289, Epsilon: 0.200
# Episode 50, Avg Reward: -7418.57, Avg Loss: 185.7137, Epsilon: 0.190
# Episode 100, Avg Reward: -7418.76, Avg Loss: 185.5395, Epsilon: 0.180
# Episode 150, Avg Reward: -7379.97, Avg Loss: 185.1937, Epsilon: 0.171
# Early stopping at episode 175 due to no improvement
#
# Example produced alignments:
#   ['-QN-S---I------F--AK-D-EA-H-DV-SR--M----', '------EN-MI---F--A--K-D--EAH------E-INRM', 'E-NSIF----AKDE--HEI-S-RMWD-L--K---------']
#   ['----Q--NS--IFAK-D--EAH-D--------VS-R----', '--E--NM--IF----A------K--DEAHEIN----R-MW', 'ENSI-FA--KDE---H-EI-S-R-M-WD--LK--------']
#   ['--QN--S---IF---A--K--D-EA------H-D----V-', '---E---N-----MI-FA-K-----DEA--H--EINRM--', 'EN--SI--FA--K-D-E---H-E--IS-RM--W--D-L-K']
#
# Evaluation for Level 7-9:
#   Average Reward: -7473.09 ± 649.68
#   Average SP Score: -2.59 ± 1.19
#   Perfect Match Rate: 0.00
#   Column Accuracy: 0.00
#   Avg Alignment Length: 40.0
# Error processing intellialign: Object of type ndarray is not JSON serializable

# %% [markdown]
# ### Plotting

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.decomposition import PCA
import pandas as pd

# Create plots directory
os.makedirs("plots", exist_ok=True)

def save_selected_plots(all_results):
    """Save the 5 selected plots for the paper"""
    
    # 1. Key Metrics Comparison
    plt.figure(figsize=(12, 8))
    metrics_to_show = ['avg_reward', 'avg_sp_score', 'perfect_match_rate']
    methods = list(all_results.keys())
    colors = plt.cm.viridis(np.linspace(0, 1, len(methods)))
    
    x = np.arange(len(metrics_to_show))
    width = 0.8 / len(methods)
    
    for i, method in enumerate(methods):
        avg_values = []
        for metric in metrics_to_show:
            values = [data['eval_results'][metric] 
                     for data in all_results[method]['results'].values()]
            avg_values.append(np.mean(values))
        
        plt.bar(x + i*width, avg_values, width, color=colors[i], label=method)
    
    plt.title("Key Metrics Comparison Across Scoring Methods")
    plt.xticks(x + width*(len(methods)-1)/2, 
              ['Avg Reward', 'Avg SP Score', 'Perfect Match %'])
    plt.ylabel("Score")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig("plots/key_metrics_comparison.png")
    plt.close()
    
    # 2. Reward vs SP Score Correlation
    plt.figure(figsize=(10, 8))
    for i, method in enumerate(methods):
        rewards = []
        sp_scores = []
        for data in all_results[method]['results'].values():
            rewards.append(data['eval_results']['avg_reward'])
            sp_scores.append(data['eval_results']['avg_sp_score'])
        
        plt.scatter(rewards, sp_scores, color=colors[i], s=100, alpha=0.7, label=method)
        z = np.polyfit(rewards, sp_scores, 1)
        p = np.poly1d(z)
        plt.plot(rewards, p(rewards), color=colors[i], linestyle='--', alpha=0.5)
    
    plt.title("Reward vs SP Score Correlation")
    plt.xlabel("Average Reward")
    plt.ylabel("Average SP Score")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig("plots/reward_sp_correlation.png")
    plt.close()
    
    # 3. Perfect Match Rate by Level
    plt.figure(figsize=(12, 8))
    for i, method in enumerate(methods):
        levels = sorted(set(data['level'] for data in all_results[method]['results'].values()))
        perfect_rates = []
        for level in levels:
            level_data = [data['eval_results']['perfect_match_rate'] 
                         for data in all_results[method]['results'].values() 
                         if data['level'] == level]
            perfect_rates.append(np.mean(level_data))
        
        plt.plot(levels, perfect_rates, 'o-', color=colors[i], label=method, linewidth=2.5)
    
    plt.title("Perfect Match Rate by Curriculum Level")
    plt.xlabel("Curriculum Level")
    plt.ylabel("Perfect Match Rate")
    plt.xticks(range(1, 8))
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig("plots/perfect_match_by_level.png")
    plt.close()
    
    # 4. SP Score vs True Alignment Match Rate
    plt.figure(figsize=(10, 8))
    true_rates = {data['level']: data['eval_results']['perfect_match_rate'] 
                 for data in all_results['true']['results'].values()}
    
    methods_rq2 = [m for m in methods if m != 'true']
    for i, method in enumerate(methods_rq2):
        sp_scores = []
        match_rates = []
        for data in all_results[method]['results'].values():
            level = data['level']
            sp_scores.append(data['eval_results']['avg_sp_score'])
            match_rates.append(true_rates.get(level, 0))
        
        corr = np.corrcoef(sp_scores, match_rates)[0,1]
        sc = plt.scatter(sp_scores, match_rates, color=colors[i], 
                        label=f"{method} (r={corr:.2f})", alpha=0.7)
        z = np.polyfit(sp_scores, match_rates, 1)
        p = np.poly1d(z)
        plt.plot(sp_scores, p(sp_scores), color=colors[i], linestyle='--')
    
    plt.title("SP Score vs True Alignment Match Rate")
    plt.xlabel("SP Score")
    plt.ylabel("True Alignment Match Rate")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig("plots/sp_vs_true_match.png")
    plt.close()
    
    # 5. Alignment Quality Divergence Heatmap
    plt.figure(figsize=(12, 8))
    true_alignments = {data['level']: data['eval_results']['perfect_match_rate'] 
                      for data in all_results['true']['results'].values()}
    
    divergence = []
    for method in methods:
        method_rates = []
        for level in range(1, 8):
            level_data = [data['eval_results']['perfect_match_rate'] 
                         for data in all_results[method]['results'].values() 
                         if data['level'] == level]
            method_rates.append(np.mean(level_data) if level_data else 0)
        divergence.append([abs(m - true_alignments.get(level, 0)) for level, m in zip(range(1,8), method_rates)])
    
    sns.heatmap(divergence, cmap="YlOrRd", 
                xticklabels=range(1,8), yticklabels=methods,
                annot=True, fmt=".2f")
    plt.title("Alignment Quality Divergence from True Alignment")
    plt.xlabel("Curriculum Level")
    plt.ylabel("Scoring Method")
    plt.tight_layout()
    plt.savefig("plots/divergence_heatmap.png")
    plt.close()

    # 6. SP Score Distribution by Method
    plt.figure(figsize=(12, 8))    
    sp_data = []
    for method in methods:
        for data in all_results[method]['results'].values():
            sp_data.append({
                'Method': method,
                'SP Score': data['eval_results']['avg_sp_score']
            })
    
    df = pd.DataFrame(sp_data)
    sns.violinplot(data=df, x='Method', y='SP Score', palette=colors)
    plt.title("SP Score Distribution by Method")
    plt.xticks(rotation=45)
    
    plt.tight_layout()
    plt.savefig("plots/sp_distribution.png")
    plt.close()

# Generate and save plots
save_selected_plots(all_results_on_easy_curriculum)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_8604\2582574440.py:154: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Method', y='SP Score', palette=colors)
# C:\Users\PC\AppData\Local\Temp\ipykernel_8604\2582574440.py:154: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   sns.violinplot(data=df, x='Method', y='SP Score', palette=colors)

# %%
def plot_divergence_heatmap(all_results):
    plt.figure(figsize=(12, 8))
    
    # Get true alignment rates by level
    true_rates = {
        data['level']: data['eval_results']['perfect_match_rate'] 
        for data in all_results['true']['results'].values()
    }
    
    # Calculate divergence for each method
    methods = [m for m in all_results.keys() if m != 'true']  # Exclude 'true' itself
    levels = sorted(set(data['level'] for data in all_results['true']['results'].values()))
    
    divergence = []
    for method in methods:
        method_rates = []
        for level in levels:
            level_data = [
                data['eval_results']['perfect_match_rate'] 
                for data in all_results[method]['results'].values() 
                if data['level'] == level
            ]
            avg_rate = np.mean(level_data) if level_data else 0
            true_rate = true_rates.get(level, 0)
            method_rates.append(abs(avg_rate - true_rate))
        divergence.append(method_rates)
    
    # Plot heatmap
    sns.heatmap(
        divergence, 
        cmap="YlOrRd", 
        xticklabels=levels, 
        yticklabels=methods,
        annot=True, 
        fmt=".2f",
        linewidths=0.5
    )
    
    plt.title("Divergence from True Alignment by Level", pad=20)
    plt.xlabel("Curriculum Level")
    plt.ylabel("Alignment Method")
    plt.tight_layout()
    plt.savefig("plots/divergence_heatmap.png")
    plt.close()

plot_divergence_heatmap(all_results_on_easy_curriculum)

# %%
def plot_state_sp_correlation(all_results):
    """Plot correlation between state features and SP scores"""
    plt.figure(figsize=(15, 6))
    
    # Get feature importance from evaluation
    methods = list(all_results.keys())
    feature_importances = []
    
    for method in methods:
        # Collect all feature importance arrays for this method
        imp_arrays = []
        for data in all_results[method]['results'].values():
            if 'state_feature_importance' in data['eval_results']:
                imp = data['eval_results']['state_feature_importance']
                if imp is not None and len(imp) > 0:
                    # Convert to numpy array and replace NaN with 0
                    arr = np.nan_to_num(np.array(imp), nan=0.0)
                    imp_arrays.append(arr)
        
        if imp_arrays:
            # Find the maximum length across all arrays
            max_len = max(len(arr) for arr in imp_arrays)
            # Pad shorter arrays with zeros
            padded_arrays = []
            for arr in imp_arrays:
                if len(arr) < max_len:
                    padded = np.zeros(max_len)
                    padded[:len(arr)] = arr
                    padded_arrays.append(padded)
                else:
                    padded_arrays.append(arr)
            
            # Calculate average importance (ignoring zeros from padding)
            avg_imp = np.mean(padded_arrays, axis=0)
            feature_importances.append((method, avg_imp))
    
    # Plot if we have data
    if feature_importances:
        # Get the first method's feature importance to determine groups
        _, first_imp = feature_importances[0]
        n_features = len(first_imp)
        
        # Define feature groups based on your state representation
        # These numbers should match your state vector construction
        aa_features = len(Config.AMINO_ACIDS)  # Number of amino acids
        lookahead_features = 3 * aa_features   # 3 lookahead positions
        progress_features = 2 * 7              # Assuming 7 sequences (2 features per seq)
        gap_features = 4                       # 4 gap context features
        
        # Calculate group boundaries
        group_boundaries = [
            ('AA Composition', 0, aa_features),
            ('Lookahead 1', aa_features, aa_features),
            ('Lookahead 2', 2*aa_features, aa_features),
            ('Lookahead 3', 3*aa_features, aa_features),
            ('Progress', 4*aa_features, progress_features),
            ('Gap Context', 4*aa_features + progress_features, gap_features)
        ]
        
        # Verify we're not exceeding available features
        total_defined = sum(g[2] for g in group_boundaries)
        if total_defined < n_features:
            group_boundaries.append(('Other', total_defined, n_features - total_defined))
        
        # Prepare data for plotting
        plot_data = []
        for method, imp in feature_importances:
            for group, start, length in group_boundaries:
                end = start + length
                if end > len(imp):
                    end = len(imp)
                if start < end:
                    group_mean = np.mean(imp[start:end])
                    plot_data.append({'Method': method, 'Feature Group': group, 'Mean Correlation': group_mean})
        
        # Convert to DataFrame for easier plotting
        df = pd.DataFrame(plot_data)
        
        # Create the plot
        plt.figure(figsize=(14, 6))
        sns.barplot(data=df, x='Feature Group', y='Mean Correlation', hue='Method', 
                   palette='viridis', errorbar=None)
        
        plt.title("State Feature Correlation with SP Scores by Group")
        plt.ylabel("Absolute Correlation Coefficient")
        plt.legend(title="Method")
        plt.grid(True, alpha=0.3)
        
        # Rotate x-axis labels if needed
        if len(group_boundaries) > 5:
            plt.xticks(rotation=45, ha='right')
        
        plt.tight_layout()
        plt.savefig("plots/state_sp_correlation.png")
        plt.close()
    else:
        print("Warning: No state feature importance data found in results")

plot_state_sp_correlation(all_results_on_easy_curriculum)

# %%
def plot_normalized_metrics_radar(all_results):
    """Plot normalized key metrics using a radar chart"""
    # Metrics to compare (use same as before)
    metrics = ['avg_reward', 'avg_sp_score', 'perfect_match_rate']
    metric_labels = ['Avg Reward', 'Avg SP Score', 'Perfect Match %']
    methods = list(all_results.keys())
    
    # Normalize each metric to [0,1] range across methods
    normalized_data = {}
    for metric in metrics:
        # Get all values for this metric across methods
        values = []
        for method in methods:
            method_values = [data['eval_results'][metric] 
                           for data in all_results[method]['results'].values()]
            values.append(np.mean(method_values))
        
        # Normalize (min-max scaling)
        min_val, max_val = min(values), max(values)
        for i, method in enumerate(methods):
            if max_val - min_val > 0:
                norm_val = (values[i] - min_val) / (max_val - min_val)
            else:
                norm_val = 0.5  # if all values are equal
            normalized_data.setdefault(method, []).append(norm_val)
    
    # Prepare radar plot
    angles = np.linspace(0, 2*np.pi, len(metrics), endpoint=False).tolist()
    angles += angles[:1]  # Close the loop
    
    fig, ax = plt.subplots(figsize=(10, 10), subplot_kw={'polar': True})
    
    # Plot each method
    colors = plt.cm.viridis(np.linspace(0, 1, len(methods)))
    for idx, method in enumerate(methods):
        values = normalized_data[method]
        values += values[:1]  # Close the loop
        ax.plot(angles, values, color=colors[idx], linewidth=2, label=method)
        ax.fill(angles, values, color=colors[idx], alpha=0.25)
    
    # Customize plot
    ax.set_theta_offset(np.pi/2)
    ax.set_theta_direction(-1)
    ax.set_thetagrids(np.degrees(angles[:-1]), metric_labels)
    
    # Set yticks to show original scale reference
    ax.set_rlabel_position(180)
    plt.yticks([0, 0.5, 1], ["Worst", "Medium", "Best"], color="grey", size=8)
    plt.ylim(0, 1)
    
    plt.title("Normalized Performance Comparison", pad=20)
    plt.legend(loc='upper right', bbox_to_anchor=(1.3, 1.1))
    plt.tight_layout()
    plt.savefig("plots/normalized_metrics_radar.png", dpi=300, bbox_inches='tight')
    plt.close()

plot_normalized_metrics_radar(all_results_on_easy_curriculum)

# %%
def plot_metrics_small_multiples(all_results):
    """Plot each metric in its own subplot"""
    metrics = {
        'avg_reward': 'Avg Reward',
        'avg_sp_score': 'Avg SP Score', 
        'perfect_match_rate': 'Perfect Match %'
    }
    methods = list(all_results.keys())
    colors = plt.cm.viridis(np.linspace(0, 1, len(methods)))
    
    fig, axes = plt.subplots(1, len(metrics), figsize=(15, 5))
    
    for ax, (metric, label) in zip(axes, metrics.items()):
        # Calculate means for each method
        method_means = []
        for method in methods:
            values = [data['eval_results'][metric] 
                     for data in all_results[method]['results'].values()]
            method_means.append(np.mean(values))
        
        # Plot with separate y-scales
        ax.bar(methods, method_means, color=colors)
        ax.set_title(label)
        ax.tick_params(axis='x', rotation=45)
        
        # Add value labels
        for i, v in enumerate(method_means):
            ax.text(i, v, f"{v:.2f}", ha='center', va='bottom')
    
    plt.suptitle("Key Metrics Comparison", y=1.05)
    plt.tight_layout()
    plt.savefig("plots/metrics_small_multiples.png", dpi=300)
    plt.close()

plot_metrics_small_multiples(all_results_on_easy_curriculum)
